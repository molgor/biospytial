# %%
from django.contrib.gis.geos import GEOSGeometry
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-2d17f93f3834> in <module>()
# ----> 1 from django.contrib.gis.geos import GEOSGeometry
#
# /home/juan/git-projects/django/django/contrib/gis/geos/__init__.py in <module>()
#       3 for more details: https://docs.djangoproject.com/en/dev/ref/contrib/gis/geos/
#       4 """
# ----> 5 from .collections import (  # NOQA
#       6     GeometryCollection, MultiLineString, MultiPoint, MultiPolygon,
#       7 )
#
# /home/juan/git-projects/django/django/contrib/gis/geos/collections.py in <module>()
#       9 from django.contrib.gis.geos import prototypes as capi
#      10 from django.contrib.gis.geos.error import GEOSException
# ---> 11 from django.contrib.gis.geos.geometry import GEOSGeometry, LinearGeometryMixin
#      12 from django.contrib.gis.geos.libgeos import geos_version_info, get_pointer_arr
# ...
