# %% [markdown]
# # Spatial Analysis with Bios*Py*tial

# %% [markdown]
# The previous section was necessary to generate the grids needed for certain tools included in the BiosPytial suite. In this section we are going to focus on a grid cell and derive a NestedTaxonomy on it. Represent the diferent arrangements of taxa at different taxonomic levels and explore the relationship between the taxa and an expert ecosystems' classification.

# %% [markdown]
# ## The Ecoregions classification

# %% [markdown]
# Para la generación de las ecorregiones se efectuaron dos talleres donde se convocaron a prominentes especialistas en el tema, quienes aportaron sus opiniones e información. Con el propósito de integrar la información disponible se formaron grupos de trabajo para áreas específicas del país, el resultado de este trabajo sirvió como base para la elaboración de la cobertura digital. Se usaron los polígonos de vegetación primaria del mapa de INEGI (2003), mediante la selección de los polígonos que conformarían cada ecorregión, tomando como primer criterio la cercanía a los trazos de las ecorregiones de nivel III de la CCA (1997), pero existiendo la libertad de que dichos trazos se modificaran en los casos en que el grupo de expertos así lo decidiera. Posteriormente se realizó una disolución de trazos innecesarios hacia el interior de cada ecorregión, para generar polígonos únicos. Cabe señalar que desde el primer taller se decidió que existirían algunas ecorregiones que podrían estar disyuntas y estar conformadas por varios polígonos de extensión variable. Tras un período de edición, la cobertura digital se envió como una propuesta preliminar para su valoración por parte de los expertos, quienes se reunieron en un segundo taller para corroborar o corregir la delimitación de cada una de las ecorregiones. El mapa tras su corrección, edición y distribución se liberó como una versión consenso preliminar. El acuerdo fue que esta definición de ecorregiones correpondería al nivel III de las 'Regiones ecológicas de América del Norte' de la CCA (1997). No obstante, al reunirse el grupo de trabajo de la CCA en New Port Oregón (del 12 al 14 de abril de 2006) se resaltó que el mapa tenía demasiado detalle en cuanto el número de regiones para ese nivel, razón por la que se redujo el numero de ecorregiones de 76 a 40. Por esta adecuación, el INEGI y la CONABIO decidieron respetar el acuerdo emanado de la reunión de New Port y pasar las ecorregiones terrestres de México resultantes de los talleres a un nivel IV. Paralelamente a los cambios hechos en la reunión de New Port, el mapa de ecorregiones terrestres nivel III resultado de los talleres, fue criticado respecto a la delimitación de los desiertos de Sonora, Chihuahua y Baja California por el Dr. Exequiel Ezcurra. Tras una revisión de los argumentos, a favor y en contra de las delimitaciones de estas regiones y de aclarar que la delimitación para México se haría al nivel IV, se decidió hacer un encuentro bilateral entre el INEGI, el Dr. Ezcurra y la CONABIO para resolver las diferencias y llegar así a una versión final del mapa que satisfaciera a las partes en disputa. Para la delimitación de algunas ecorregiones se usaron algunos trazos de los Datos Vectoriales Topográficos de INEGI (2000), Datos Vectoriales Edafológicos de INEGI y Datos Vectoriales Geológicos de INEGI, seleccionando el o los trazos necesarios para generar el límite correspondiente. El trazo o trazos seleccionados fueron extraídos del mapa fuente e incorporados al mapa de ecorregiones. Esta segunda versión del mapa de Ecorregiones terrestres de México hace correcciones respecto al trazo de una ecorregión así como la corrección de sinonimias encontradas entrre dos pares de ecorregiones.

# %% [markdown]
# ### California Mediterránea

# %% [markdown]
# Esta región ecológica relativamente pequeña, se extiende desde Oregon, en el norte de Estados Unidos, 1,300 km hacia el sur hasta Baja California Norte, en México. Colinda con el océano Pacífico al oeste y al este con la Sierra Nevada y los desiertos. Se distingue por su clima mediterráneo cálido y templado, su vegetación arbustiva de chaparral mixto con áreas de pastizales y bosques abiertos de encinos, por sus valles agrícolas productivos y por su alta población (30 millones de habitantes) en extensas aglomeraciones urbanas.

# %% [markdown]
# ### Desiertos de América del Norte

# %% [markdown]
# Se extienden de la parte oriental de Columbia Británica hasta Baja California y la parte norte-centro de México. Se diferencia de las regiones forestales montañosas adyacentes por su aridez, vegetación única de arbustos y cactos, carencia de árboles y, generalmente, relieves y elevaciones bajas. Los centros de población han sido históricamente pequeños, aunque en tiempos recientes varias áreas urbanas como Las Vegas han experimentado un rápido crecimiento.
# Esta región ecológica tiene un clima desértico estepario, de árido a semiárido, con temperaturas extremas estacionales.

# %% [markdown]
# ### Elevaciones Semiáridas Meridionales

# %% [markdown]
#
# Se extiende sobre parte de Arizona y Nuevo México, en Estados Unidos, y hacia el sur sobre varios de los estados del norte, oeste y centro de México. En territorio mexicano la región limita al occidente con las Sierras Templadas y al este con la región ecológica de los Desiertos de América del Norte. El paisaje se compone de colinas, valles bajos y planicies. En general la vegetación en esta región está dominada por pastizales y, en las zonas de transición, matorrales y bosques.

# %% [markdown]
# ### Grandes Planicies

# %% [markdown]
# Se ubica en la parte central del continente y se extiende en el rango latitudinal más amplio de las demás regiones ecológicas de América del Norte. Es un área relativamente continua y más o menos triangular que cubre alrededor de 3.5 millones de kilómetros cuadrados. Las planicies de América del Norte se extienden alrededor de 1,500 km desde Alberta, Saskatchewan y Manitoba en Canadá hacia el sur a lo largo de las Grandes Planicies de Estados Unidos hasta el sur de Texas adyacente a México, y aproximadamente 600 km desde el oeste de Indiana hasta el pie de las Rocallosas y el noreste de México. Esta región ecológica se distingue en particular por su relativamente poco relieve topográfico, pastizales, escasez de bosques y clima de subhúmedo a semiárido.

# %% [markdown]
# ### Selvas Cálido-Húmedas

# %% [markdown]
#
# Esta región ecológica incluye el extremo sur de la península de Florida en Estados Unidos y, en México, circunda la Planicie Costera del Golfo, la parte occidental y sur de la Planicie Costera del Pacífico, la parte más alta de la península de Yucatán y las porciones bajas de la Sierra Madre de Chiapas, desde donde continúa al sur hacia Centro y Sudamérica.

# %% [markdown]
# ### Selvas Cálido-Secas

# %% [markdown]
# Esta región ecológica se extiende en una angosta y discontinua franja desde el este de Sonora y el sureste de Chihuahua hasta Chiapas; en Michoacán incluye la cuenca del Balsas. En el Istmo de Tehuantepec se parte para rodear la Depresión Central de Chiapas, en donde se extiende a lo largo del Pacífico hacia América Central y el extremo norte de América del Sur. También ocupa el norte de la planicie costera del Golfo, el norte de la península de Yucatán y la franja sur de la península de Baja California, cubriendo aproximadamente 13% de México.

# %% [markdown]
# ### Sierras Templadas

# %% [markdown]
# La región comprende las principales montañas mexicanas incluidas la Sierra Madre Occidental, la Sierra Madre Oriental y los complejos montañosos de Chiapas y Oaxaca. La región cubre alrededor de 25 por ciento de México. Muchas de las principales ciudades del país se localizan en esta unidad: la Ciudad de México, Guadalajara, Morelia, Toluca, Puebla. Aproximadamente 40 millones de personas habitan esta región, sometida a uso intensivo agrícola e industrial.

# %% [markdown]
# 'http://www.conabio.gob.mx/informacion/metadata/gis/ecort08gw.xml?_xsl=/db/metadata/xsl/fgdc_html.xsl&_indent=no'

# %% [markdown]
# ## Select an adecquate Grid Cell

# %% [markdown]
# The region of central-south Mexico shows an interesting representation of several *Ecoregions* and, when overlaped with the GBIF occurrences it is clear that has a good amount of *Occurrences* (See figure below)

# %%
from IPython.display import Image
Image(filename='docs/_static/ecoregions_center.png')

# %% [markdown]
# Therefore the cell 36 from the grid ´mexico_grid8´is a good candidate for generating the NestedTaxonomy.

# %% [markdown]
# ### Import necessary modules

# %%
from gbif.taxonomy import NestedTaxonomy
from gbif.models import Occurrence
# Out:
# No module named MySQLdb
#  MySQLdb module could not be loaded

# %%
biosphere = Occurrence.objects.all()

# %%
nt = NestedTaxonomy(36,biosphere,start_level=3,end_level=9,generate_tree_now=False)
# Out:
# INFO [biospatial.gbif.taxonomy.embedTaxonomyinNestedGrid] Embeding local biomes in grid
# INFO:biospatial.gbif.taxonomy:[biospatial.gbif.taxonomy.embedTaxonomyinNestedGrid] Embeding local biomes in grid
# INFO [biospatial.gbif.taxonomy.embedTaxonomyinNestedGrid] Embeding local biomes in grid
# INFO:biospatial.gbif.taxonomy:[biospatial.gbif.taxonomy.embedTaxonomyinNestedGrid] Embeding local biomes in grid
# INFO [biospatial.gbif.taxonomy.embedTaxonomyinNestedGrid] Embeding local biomes in grid
# INFO:biospatial.gbif.taxonomy:[biospatial.gbif.taxonomy.embedTaxonomyinNestedGrid] Embeding local biomes in grid
# INFO [biospatial.gbif.taxonomy.embedTaxonomyinNestedGrid] Embeding local biomes in grid
# INFO:biospatial.gbif.taxonomy:[biospatial.gbif.taxonomy.embedTaxonomyinNestedGrid] Embeding local biomes in grid
# INFO [biospatial.gbif.taxonomy.embedTaxonomyinNestedGrid] Embeding local biomes in grid
# ...

# %% [markdown]
# The Nested Taxonomy has been created but the Tree representations and other calculations regarding richness
# haven't been performed. This is because when the flag ´generate_tree_now´ is set to False the object remains declared as a LazyQuery. This is usefull when the object is stored in the Cache System and it's not necessary to calculate again everything.
# No worries, we are going to see this in a while.
#
# Let's explore ´nt´

# %%
print nt.levels
# Out:
# {3: <GriddedTaxonomy instance: 36@mesh"."mexico_grid8 >, 4: <GriddedTaxonomy instance: 36@mesh"."mexico_grid16 >, 5: <GriddedTaxonomy instance: 36@mesh"."mexico_grid32 >, 6: <GriddedTaxonomy instance: 36@mesh"."mexico_grid64 >, 7: <GriddedTaxonomy instance: 36@mesh"."mexico_grid128 >, 8: <GriddedTaxonomy instance: 36@mesh"."mexico_grid256 >, 9: <GriddedTaxonomy instance: 36@mesh"."mexico_grid512 >}

# %% [markdown]
# Let parent be the GriddedTaxonomy at level 3.
#
# For calculating the richness at all taxonomic levels in this Grid execute:

# %%
#nt.parent.calculateRichness()

# %%
richness_for_level_3 = {'classes': 93,
 'families': 1861,
 'genera': 8196,
 'kingdoms': 5,
 'occurrences': 791525,
 'orders': 468,
 'phyla': 32,
 'species': 25988}

# %% [markdown]
# ## Partitionate the *biosphere* in different Ecoregions

# %% [markdown]
# The Ecoregions map is defined in the Mexican territory. The amount of Occurrences spreaded in this region is huge (circa: 4 Millions).
# For now this analysis will focus on the region bounded by the Cell 36 defined by the grid: `mexico_grid8`
#
# **Summary**
#
# Let $biosphere$ be the set of Occurrences in the surface of the Earth and $E_k$ the Ecoregions corresponding to the class $k$. Every $E_k$ is a compact set that has certain ecological properties, as explained before.
#
# **Definition**
#
# $bios_k \subset biosphere$ given by $\{ x \in biosphere \wedge x $ geometrically within the $E_k \}$

# %%
study_area = nt.parent.biomeGeometry

# %%
from ecoregions.models import Ecoregion
ecoregions = Ecoregion.objects.all()
ecoregions_in_area = ecoregions.filter(geom__within=study_area)

# %% [markdown]
# Lets preprocess this first.
#
# * Take a member for each class using the *num_zona* attribute.

# %%
#zonenumbers = list(set(map(lambda e : e.num_zona,ecoregions_in_area)))
print ecoregions_in_area
# Out:
# [<Ecoregion: instance 1434 :: Templada subh�meda >, <Ecoregion: instance 1216 :: Cuerpo de Agua >, <Ecoregion: instance 961 :: Tropical h�meda >, <Ecoregion: instance 962 :: Templada subh�meda >, <Ecoregion: instance 897 :: Templada subh�meda >, <Ecoregion: instance 898 :: Templada subh�meda >, <Ecoregion: instance 899 :: Templada subh�meda >, <Ecoregion: instance 902 :: Templada h�meda >, <Ecoregion: instance 905 :: Templada subh�meda >, <Ecoregion: instance 906 :: Inundable o Transici�n tierra-mar >, <Ecoregion: instance 907 :: Tropical h�meda >, <Ecoregion: instance 988 :: Tropical h�meda >, <Ecoregion: instance 1257 :: �rida y semi�rida >, <Ecoregion: instance 909 :: Templada subh�meda >, <Ecoregion: instance 911 :: Inundable o Transici�n tierra-mar >, <Ecoregion: instance 912 :: Templada h�meda >, <Ecoregion: instance 913 :: Tropical h�meda >, <Ecoregion: instance 917 :: Templada subh�meda >, <Ecoregion: instance 1258 :: Templada h�meda >, <Ecoregion: instance 921 :: Templada su
# ...

# %%
zonenumbers = list(set(map(lambda e : e.num_zona,ecoregions_in_area)))

# %% [markdown]
# There are some objects with the zone number = 'None'. We do not need that, let's filter that.

# %%
z_numbers = filter(lambda x : x != None,zonenumbers)

# %%
print z_numbers
# Out:
# [u'1', u'3', u'2', u'5', u'4', u'7', u'6']

# %% [markdown]
# Now we are going to build a dictionary structured by the zone name, zone_id and the polygon made by the Union of the polygons of the same class.
#
# For achieving this we need to import some aggregation modules.

# %%
print regions_dic
# Out:
# {1: {'zone_id': u'1', 'name': u'Tropical h\xa3meda', 'polygon': <MultiPolygon object at 0x11ad44130>}, 2: {'zone_id': u'2', 'name': u'Tropical subh\xa3meda', 'polygon': <MultiPolygon object at 0x11ad44250>}, 3: {'zone_id': u'3', 'name': u'Templada h\xa3meda', 'polygon': <MultiPolygon object at 0x11ad441c0>}, 4: {'zone_id': u'4', 'name': u'Templada subh\xa3meda', 'polygon': <MultiPolygon object at 0x11ad44370>}, 5: {'zone_id': u'5', 'name': u'\xb5rida y semi\xa0rida', 'polygon': <MultiPolygon object at 0x11ad442e0>}, 6: {'zone_id': u'6', 'name': u'Alpina', 'polygon': <MultiPolygon object at 0x11ad44490>}, 7: {'zone_id': u'7', 'name': u'Inundable o Transici\xa2n tierra-mar', 'polygon': <MultiPolygon object at 0x11ad44400>}}

# %% [markdown]
# Lets calculate the richness at the bottom level. This can be achieved with this:

# %%
richness = map(lambda tax : tax.calculateRichness(),nt.levels[9].taxonomies)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b7d99505e966> in <module>()
# ----> 1 richness = map(lambda tax : tax.calculateRichness(),nt.levels[9].taxonomies)
#
# NameError: name 'nt' is not defined

# %% [markdown]
# To create a shapefile map with this information run:

# %%
nt.levels[9].createShapefile(store='mexico_center_richness')

# %%
from IPython.display import Image
Image(filename='docs/_static/mex_cent_rich.png')

# %% [markdown]
# ### Select all the tropical subhumid regions

# %% [markdown]
# Load the taxonomies from the GriddedTaxonomies 9

# %%
l9 = nt.levels[9]

# %%
import redis

# %% [raw]
# r = redis.StrictRedis()

# %%
l9.restoreTaxonomiesFromCache(r)
INFO Restored Taxonomy: 0/4096 
INFO Restored Taxonomy: 1/4096  
INFO Restored Taxonomy: 2/4096 
INFO Restored Taxonomy: 3/4096 
...
INFO Restored Taxonomy: 4095/4096 
INFO Restored Taxonomy: 4096/4096 
INFO All taxonomies restored

# %%
If the taonomies are not present in the Caching System you can calculate the inner trees with:

# %% [markdown]
# For generating the Tree Data Structure of all the taxonomies involved run:

# %%
map(lambda l_t : map(lambda t : t.buildInnerTree(deep=True),l_t),tropic_tax)

# %% [markdown]
# This will calculate the InnerTree in all the taxonomies in tropic_tax. We are ready to evaluate all the taxonomic invariants
# within this type of Ecoregion.

# %% [markdown]
# To calculate the intrinsic complexity use:

# %%
map(lambda l_t : map(lambda t : t.calculateIntrinsicComplexity(),l_t),tropic_tax)

# %% [markdown]
# ## Creating subsets of polygons based on the Ecoregion type

# %% [markdown]
# Two datasets to create
#
#  * Using several polygons for each ecoregion type
#  * Merging the polygons into one for each ecoregion type. (i.e. One polygon for each ecoregion)

# %% [markdown]
# ### Using single polygons:

# %%
regions_singpol_dic = {}
for i in z_numbers:
    regions_singpol_dic[int(i)] = map(lambda p : p.geom , ecoregions_in_area.filter(num_zona=int(i)))

# %% [markdown]
# ### Using merged polygons:

# %%
from django.contrib.gis.db.models import Union, Min
regions_polys_merged = {}
for i in z_numbers:
    regions_polys_merged[int(i)]=ecoregions_in_area.filter(num_zona=int(i)).aggregate(polygon=Union('geom'),name=Min('nomzonecol'.encode('latin-1')),zone_id=Min('num_zona'))

# %% [markdown]
# ## Creating subsets of Taxonomies based on spatial Joins with the merged and single polygons

# %% [markdown]
# ### Using the single polygon subset

# %%
taxonomies_per_ecoregion_sngpol = {}
for i in z_numbers:
    tax_list = []
    for poly in regions_singpol_dic[int(i)]:
        tax_list.append(filter(lambda t : t.biomeGeometry.intersects(poly),l9.taxonomies))
        taxonomies_per_ecoregion_sngpol[i] = tax_list

# %% [markdown]
# The output is a dictionary of Multipolygon lists. Each item in the dictionary is an ecoregional type and each value is a composition
# of lists. Each of the entries (lists) are the taxonomies that are intersects with each Multipolygon object.
# In the following case we will have the polygons with out merging. i.e. if they are from class 1 each polygon will be treat as separate.

# %% [markdown]
# ### Using the merged polygons

# %%
taxonomies_per_ecoregion_mergpol = {}
for i in z_numbers:
    poly = regions_polys_merged[int(i)]['polygon']
    tax_list = filter(lambda t : t.biomeGeometry.intersects(poly),l9.taxonomies)
    taxonomies_per_ecoregion_mergpol[int(i)] = tax_list

# %% [markdown]
# To do now: take average on the ratios and standard deviations.
#
#     Do all these for the rest of the classes
#
#     Do all these with the merged polygon classes
#
#     See if the resultas are similar.
#
#     Try to find any pattern or variation between invariants.

# %% [raw]
# %time nt.parent.buildInnerTree(deep=True)
# 2 hours approx.

# %% [markdown]
# INFO [gbif.taxonomy.obtainPartialTrees()] Species level does not exist for this taxonomy (grid cell). Calculating it now!
# INFO [gbif.buildtree] Collapsing Orders
# INFO [gbif.buildtree] Collapsing Classes
# INFO [gbif.buildtree] Collapsing Phyla
# INFO [gbif.buildtree] Collapsing Kingdoms
# INFO [gbif.taxonomy.obtainPartialTrees()] Pruning trees
# INFO [gbif.taxonomy.obtainPartialTrees()] Pruning trees
# CPU times: user 1min 50s, sys: 13.7 s, total: 2min 4s
# Wall time: 1h 44min 56s
# Server: Geodata

# %% [markdown]
# Let l9 the GriddedTaxonomy at level 9

# %%
l9 = nt.levels[9]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c1e9b935b421> in <module>()
# ----> 1 l9 = nt.levels[9]
#
# NameError: name 'nt' is not defined

# %% [markdown]
# if the taxonomies have been calculated previously and stored in cache they can be loaded using:

# %% [raw]
# l9.restoreTaxonomiesFromCache(r)

# %% [markdown]
# Now that the Taxonomies have been loaded in the *l9* Grid we will proceed to generate the taxonomies that are within each polygon

# %% [markdown]
# To do this first we must select the polygons based on the ecoregion's type:

# %%
regions_polys = {}
for i in z_numbers:
    #regions_dic[int(i)]=ecoregions_in_area.filter(num_zona=int(i)).aggregate(polygon=Union('geom'),name=Min('nomzonecol'.encode('latin-1')),zone_id=Min('num_zona'))
    regions_polys[int(i)]=map(lambda p : p.geom , ecoregions_in_area.filter(num_zona=int(i)))

# %%
In this case the polygons are merged by class type. Having exactly one polygon for each class.

# %%
tropic_tax = []
for tropic in regions_dic[1]:
    tropic_tax.append(filter(lambda tax  :tax.biomeGeometry.intersects(tropic.geom),l9.taxonomies))
