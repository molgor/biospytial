# %% [markdown]
# # Obtaining random cell samples
# In this exercise we will obtain a random sample of cells with its associate environmental covariates.

# %%
# %matplotlib inline
import sys
sys.path.append('/apps')
import django
django.setup()
from drivers.tree_builder import TreeNeo
from drivers.graph_models import TreeNode, Order, Family, graph,Kingdom,Occurrence
from drivers.graph_models import Cell,Mex4km, countObjectsOf
from drivers.graph_models import pickNode
import matplotlib.pyplot as plt
import pandas as pd
import itertools as it
import numpy as np

## Use the ggplot style
plt.style.use('ggplot')

# %% [markdown]
# 2. Selecting the space of considered cells.
# For this case we will consider all the Mexican Territory. We can load the Mexican polygon from the database with the following commands.
#
# > Failing to do so will likely obtain all the registered cells. In cases could hang the system.

# %%
from sketches.models import Country
from mesh.models import MexMesh
from traversals.sampling import UniformRandomCellSample

Mexico = Country.objects.filter(name__contains="exico").get()
mexican_cells = MexMesh.objects.filter(cell__intersects=Mexico.geom)

# %%
# Get all cell ids
ids = list(mexican_cells.values('pk'))
CellNodeClass = Mex4km
list_of_cell_ids = ids
sample_size = 1000
selection_of_cells = UniformRandomCellSample(ids,Mex4km,sample_size=sample_size,random_seed=12345,with_replacement=True)
# Out:
# INFO Using custom random seed of: 12345
# INFO Compiling Query and asking the Graph Database

# %% [markdown]
# The size of 'ids' is {{n}}
# 3. Generate the trees for each cell.

# %%
# %time cells = list(selection_of_cells)
# Out:
# CPU times: user 7.73 s, sys: 316 ms, total: 8.05 s
# Wall time: 23.2 s

# %% [markdown]
# 1.2 We will use the function *buildTreeNeo* to extract the taxonomic tree in that area.

# %%
from traversals import strategies as st
# %time trees = map(lambda cell : st.buildTreeNeo(cell),cells)
# Out:
# CPU times: user 3min 37s, sys: 6.21 s, total: 3min 43s
# Wall time: 4min 40s

# %% [markdown]
# ## Union of trees

# %%
# %time ocs = reduce(lambda a,b : a + b ,map(lambda t : t.occurrences, trees))
# Out:
# CPU times: user 516 ms, sys: 0 ns, total: 516 ms
# Wall time: 518 ms

# %%
## Ohh! super fast (compared to the other method that takes more than 20 minutes for this sample size)
# %time bigtree = TreeNeo(ocs,cell_objects=cells)
# Out:
# CPU times: user 1.92 s, sys: 20 ms, total: 1.94 s
# Wall time: 1.94 s

# %%
## Extract the root (if any!)
root = bigtree.to_Plantae

# %%
## Get presences absences
def PresenceAbsence(node,list_of_trees):
    pres_reps = pd.DataFrame({
    'Y' : map(
        lambda tree : tree.hasNode(node),list_of_trees)
    }).astype('int')
    return pres_reps

# %%
pres = PresenceAbsence(root,trees)

# %%
sum(pres.values)
# Out:
# array([392])

# %% [markdown]
# ## Get environmental Covariates

# %%
from traversals import strategies as st

# %time data = st.getEnvironmentalCovariatesFromListOfCells(cells)
# Out:
# CPU times: user 21.2 s, sys: 364 ms, total: 21.6 s
# Wall time: 5min 30s

# %% [markdown]
# ### Concatenate two dataframes
# > Build some utility functions for automating this tasks

# %%
training_data = pd.concat([pres,data],axis=1)

# %% [markdown]
# ## Let's save this for the moment

# %%
training_data.to_csv("/outputs/root_train.csv")

# %%
training_data
# Out:
#      Y Elevation_mean MaxTemperature_mean MeanTemperature_mean  \
# 0    0        471.333             27.9719              21.4889
# 1    0        63.2222             30.2252              20.7662
# 2    0        28.4444             32.2956              25.8333
# 3    0        3.88889              27.694              23.0694
# 4    1           2353             21.8447              13.7833
# 5    1        1567.78             26.0403              17.1597
# 6    0        1305.78             27.7722               20.794
# 7    0        1118.22             26.3725                   18
# 8    0        2079.22             23.4965              13.4931
# 9    1        1727.67             26.1475              17.5324
# 10   0        11.7778             29.7292               23.706
# 11   0        1501.33             26.4079              17.8241
# 12   0        1212.78             26.8113                 N.A.
# 13   0        581.889             25.6794              19.6806
# 14   1        2074.67             24.8775              17.1435
# 15   1              9             30.3531              26.1111
# 16   0           1900             26.6106              16.9306
# 17   1        828.333             22.8375              15.8611
# 18   1        7.16667              30.369              25.6667
# 19   0        56.8889             32.4965              26.2801
# 20   0        1191.67             27.0181              17.4884
# 21   0        283.444             30.4185              23.6551
# 22   0        27.3333             29.1725              24.2153
# 23   1        2555.56              20.872               13.338
# 24   1        676.889             26.8803              22.5139
# 25   0        1413.56             28.5861              19.6782
# 26   0        1628.78             24.0297              16.2806
# 27   0        2049.67             25.4875              16.7454
# 28   0        2266.67             23.1375              14.5972
# 29   0        1199.11             28.7604              21.3079
# ..  ..            ...                 ...                  ...
# 965  0        2635.78             20.2822              11.5139
# 966  1        2198.56             21.0949              11.8681
# 967  0            756              32.755              25.4667
# 968  1        458.444             28.4678               20.206
# 969  1        2055.67             21.7083              16.8778
# 970  0        902.167              29.731              21.2153
# 971  0        7.44444             32.4322              26.7917
# 972  0        1335.44             27.2242              18.1861
# 973  1        1513.33             24.7822              19.3028
# 974  1        2699.89             20.5787              13.1852
# 975  0        21.1667             31.2009              25.7431
# 976  0        41.3333             30.7333              25.8389
# 977  1        71.3333             27.1248              19.7917
# 978  1        56.2222             31.8253                 26.6
# 979  0        2260.44             23.9243              15.3958
# 980  1        660.111             33.0914              26.6597
# 981  1        1482.78             26.5458              19.4352
# 982  0        178.667             29.5058              21.5833
# 983  1        1259.56             27.5264              18.7153
# 984  1             45             28.9434              22.5463
# 985  0        334.889             33.2225              24.3727
# 986  0        1409.89             27.6523              19.5579
# 987  1        8.88889             30.4692              25.9537
# 988  1        1038.17             26.4796              20.4051
# 989  1           28.5              30.437              25.5972
# 990  1        1206.56             27.9602                   19
# 991  1           1626             27.2102              18.8056
# 989             30.4861            180.667             16534.3    2.58333
# 990             28.0208            27.0856             18286.3       1.25
# 991             27.2407            44.4653             17597.2    1.32639
# 992             30.8333            113.578             18537.3    2.41667
# 993             25.8958            74.2245             17280.8     1.2963
# 994             30.6181            32.9375               18983       1.25
#
#     WindSpeed_mean   Longitude   Latitude
# 0              3.4 -100.248563  26.612390
# 1          2.26389 -113.380563  27.543390
# 2          2.33333  -88.684563  20.585390
# 3          4.41667  -97.406563  25.681390
# 4          3.11389 -103.629563  22.839390
# 5          2.79861 -106.177563  28.768390
# 6          2.18519 -107.255563  25.975390
# 7          3.31389 -106.373563  31.708390
# 8          3.08333 -107.353563  28.523390
# 9          2.48843 -105.050563  25.828390
# 10         3.53704  -97.896563  24.701390
# 11         2.87731 -105.246563  28.621390
# 12            N.A. -107.500563  31.806390
# 13         2.17222 -115.291563  31.512390
# 14               2  -98.190563  18.919390
# 15         3.40972  -86.880341  20.395285
# 16         3.24722 -102.355563  23.770390
# 17         2.93981 -116.516563  32.051390
# 18         3.41667  -87.067563  21.516390
# 19         2.56713  -90.840563  18.723390
# 20            3.25 -107.353563  31.561390
# 21          2.2338  -98.974563  24.358390
# 22         2.04167  -97.847563  21.467390
# 23          2.5463  -99.758563  19.556390
# 24            2.25  -96.622563  19.654390
# 25         2.43056 -104.168563  26.073390
# 26             3.8 -104.854563  30.091390
# 27         3.25231 -102.796563  23.966390
# 28         3.11111 -105.148563  25.289390
# 29         2.58333 -102.257563  25.632390
# ..             ...         ...        ...
# 965        3.41204 -105.540563  25.338390
# 966        3.46991 -108.235563  29.993390
# 967        1.34444 -101.081563  18.870390
# 968        2.16667 -113.184563  27.592390
# 969        2.68889  -96.279563  17.008390
# 970        3.11806 -104.266563  29.356390
# 971        2.93056  -91.673563  18.135390
# 972        3.16667 -103.629563  28.327390
# 973        2.14167  -91.820563  16.322390
# 974         2.7338  -98.582563  20.046390
# 975            2.5  -88.194563  19.066390
# 976           2.75  -94.270563  17.694390
# 977        2.99769 -114.066563  27.249390
# 978        2.25556  -92.261563  17.645390
# 979         2.8912 -103.482563  22.692390
# 980        1.42361  -99.121563  17.890390
# 981        1.82407  -98.778563  20.781390
# 982        2.16667 -111.714563  25.681390
# 983        2.67361 -103.972563  27.984390
# 984        3.48148 -110.136936  23.232519
# 985              2 -108.431563  26.465390
# 986        1.91898 -105.785563  23.917390
# 987        3.93287  -94.564563  18.135390
# 988              2  -96.916563  19.115390
# 989        3.91667  -95.299898  18.706019
# 990            2.5 -105.736563  28.768390
# 991        3.06019  -99.807563  24.015390
# 992        2.23397  -89.762563  17.841390
# 993        2.22454  -97.210563  17.008390
# 994        2.61343 -111.028563  30.483390
#
# [995 rows x 11 columns]
