# %%
# %matplotlib inline
import sys
sys.path.append('/apps')
import django
django.setup()
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
## Use the ggplot style
plt.style.use('ggplot')

# %% [markdown]
# # Modelling Sampling effort
# The data is taken from the Redis database.
# This mimics the process performed in the cluster or other independent computing infrastructures.
#
# We will use the functions defined in spystats.biospytial_models

# %%
import external_plugins.spystats.biospytial_models.runner as bm
# Out:
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import redis
conn = redis.StrictRedis(host='redis',password='biospytial.')

# %%
trainkey = 't-guerrero-p3'
predkey = 'p-100x100-guerrero-poly3'
PDF = bm.preparePredictors(bm.loadDataFrameFromRedis(predkey,conn))
TDF = bm.loadDataFrameFromRedis(trainkey,conn)
# Out:
# INFO:external_plugins.spystats.biospytial_models.runner:Loading data from RedisDB
# INFO:external_plugins.spystats.biospytial_models.runner:Loading data from RedisDB

# %%
## Associate the categorical variables
TDF['name'] = TDF['name'].astype('category')
TDF['wwf_mhtnam'] = TDF['wwf_mhtnam'].astype('category')

PDF['clean']['name'] = PDF['clean']['name'].astype('category')
PDF['clean']['wwf_mhtnam'] = PDF['clean']['wwf_mhtnam'].astype('category')

PDF['full']['name'] = PDF['full']['name'].astype('category')
PDF['full']['wwf_mhtnam'] = PDF['full']['wwf_mhtnam'].astype('category')
# Out:
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
formula = 'LUCA ~ Longitude + Latitude + Q("Dist.to.road_m") + Population_m + name'

# %%
import pymc3 as pm
## Let's see first with GLM
with pm.Model() as logistic_model:
    pm.glm.GLM.from_formula(formula, TDF, family=pm.glm.families.Binomial())
    print(logistic_model.logp(logistic_model.test_point))
    trace_logistic_model = pm.sample(2000, chains=1, tune=1000)
# Out:
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# INFO:pymc3:Initializing NUTS using jitter+adapt_diag...
# -392.83837153327215
# Sequential sampling (1 chains in 1 job)
# INFO:pymc3:Sequential sampling (1 chains in 1 job)
# NUTS: [Population_m, Q("Dist.to.road_m"), Latitude, Longitude, name[T.u'VEGETACI\xd3N SECUNDARIA ARB\xd3REA DE SELVA BAJA CADUCIFOLIA'], name[T.u'VEGETACI\xd3N SECUNDARIA ARB\xd3REA DE BOSQUE MES\xd3FILO DE MONTA\xd1A'], name[T.u'VEGETACI\xd3N SECUNDARIA ARB\xd3REA DE BOSQUE DE PINO-ENCINO'], name[T.u'VEGETACI\xd3N SECUNDARIA ARB\xd3REA DE BOSQUE DE PINO'], name[T.u'VEGETACI\xd3N SECUNDARIA ARB\xd3REA DE BOSQUE DE ENCINO'], name[T.u'VEGETACI\xd3N SECUNDARIA ARBUSTIVA DE SELVA BAJA CADUCIFOLIA'], name[T.u'VEGETACI\xd3N SECUNDARIA ARBUSTIVA DE BOSQUE MES\xd3FILO DE MONTA\xd1A'], name[T.u'VEGETACI\xd3N SECUNDARIA ARBUSTIVA DE BOSQUE DE PINO-ENCINO'], name[T.u'VEGETACI\xd3N SECUNDARIA ARBUSTIVA DE BOSQUE DE PINO'], name[T.u'VEGETACI\xd3N SECUNDARIA ARBUSTIVA DE BOSQUE DE ENCINO'], name[T.SELVA MEDIANA SUBPERENNIFOLIA], name[T.SELVA BAJA CADUCIFOLIA], name[T.SABANOIDE], name[T.PASTIZAL INDUCIDO], name[T.PASTIZAL CULTIVADO], name[T.PALMAR INDUCIDO], name[T.CUERPO DE AGUA], name[T.u'BOSQUE MES\xd3FILO DE MONTA\xd1A'], name[T.u'BOSQUE DE T\xc1SCATE'], name[T.BOSQUE DE PINO-ENCINO], name[T.BOSQUE DE PINO], name[T.BOSQUE DE ENCINO-PINO], name[T.BOSQUE DE ENCINO], name[T.ASENTAMIENTOS HUMANOS], name[T.AGRICULTURA DE TEMPORAL ANUAL Y PERMANENTE], name[T.AGRICULTURA DE TEMPORAL ANUAL], Intercept]
# INFO:pymc3:NUTS: [Population_m, Q("Dist.to.road_m"), Latitude, Longitude, name[T.u'VEGETACI\xd3N SECUNDARIA ARB\xd3REA DE SELVA BAJA CADUCIFOLIA'], name[T.u'VEGETACI\xd3N SECUNDARIA ARB\xd3REA DE BOSQUE MES\xd3FILO DE MONTA\xd1A'], name[T.u'VEGETACI\xd3N SECUNDARIA ARB\xd3REA DE BOSQUE DE PINO-ENCINO'], name[T.u'VEGETACI\xd3N SECUNDARIA ARB\xd3REA DE BOSQUE DE PINO'], name[T.u'VEGETACI\xd3N SECUNDARIA ARB\xd3REA DE BOSQUE DE ENCINO'], name[T.u'VEGETACI\xd3N SECUNDARIA ARBUSTIVA DE SELVA BAJA CADUCIFOLIA'], name[T.u'VEGETACI\xd3N SECUNDARIA ARBUSTIVA DE BOSQUE MES\xd3FILO DE MONTA\xd1A'], name[T.u'VEGETACI\xd3N SECUNDARIA ARBUSTIVA DE BOSQUE DE PINO-ENCINO'], name[T.u'VEGETACI\xd3N SECUNDARIA ARBUSTIVA DE BOSQUE DE PINO'], name[T.u'VEGETACI\xd3N SECUNDARIA ARBUSTIVA DE BOSQUE DE ENCINO'], name[T.SELVA MEDIANA SUBPERENNIFOLIA], name[T.SELVA BAJA CADUCIFOLIA], name[T.SABANOIDE], name[T.PASTIZAL INDUCIDO], name[T.PASTIZAL CULTIVADO], name[T.PALMAR INDUCIDO], name[T.CUERPO DE AGUA], name[T.u'BOSQUE MES\xd3FILO DE MONTA\xd1A'], name[T.u'BOSQUE DE T\xc1SCATE'], name[T.BOSQUE DE PINO-ENCINO], name[T.BOSQUE DE PINO], name[T.BOSQUE DE ENCINO-PINO], name[T.BOSQUE DE ENCINO], name[T.ASENTAMIENTOS HUMANOS], name[T.AGRICULTURA DE TEMPORAL ANUAL Y PERMANENTE], name[T.AGRICULTURA DE TEMPORAL ANUAL], Intercept]
#   0%|          | 0/3000 [00:00<?, ?it/s]
# ValueErrorTraceback (most recent call last)
# <ipython-input-26-5b94a42a3d9f> in <module>()
#       4     pm.glm.GLM.from_formula(formula, TDF, family=pm.glm.families.Binomial())
#       5     print(logistic_model.logp(logistic_model.test_point))
# ----> 6     trace_logistic_model = pm.sample(2000, chains=1, tune=1000)
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/pymc3/sampling.pyc in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, nuts_kwargs, step_kwargs, progressbar, model, random_seed, live_plot, discard_tuned_samples, live_plot_kwargs, compute_convergence_checks, use_mmap, **kwargs)
#     460             _log.info('Sequential sampling ({} chains in 1 job)'.format(chains))
#     461             _print_step_hierarchy(step)
# --> 462             trace = _sample_many(**sample_args)
#     463
#     464     discard = tune if discard_tuned_samples else 0
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/pymc3/sampling.pyc in _sample_many(draws, chain, chains, start, random_seed, step, **kwargs)
#     508     for i in range(chains):
#     509         trace = _sample(draws=draws, chain=chain + i, start=start[i],
# --> 510                         step=step, random_seed=random_seed[i], **kwargs)
#     511         if trace is None:
#     512             if len(traces) == 0:
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/pymc3/sampling.pyc in _sample(chain, progressbar, random_seed, start, draws, step, trace, tune, model, live_plot, live_plot_kwargs, **kwargs)
#     552     try:
#     553         strace = None
# --> 554         for it, strace in enumerate(sampling):
#     555             if live_plot:
#     556                 if live_plot_kwargs is None:
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/tqdm/_tqdm.pyc in __iter__(self)
#     938 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     939
# --> 940             for obj in iterable:
#     941                 yield obj
#     942                 # Update and possibly print the progressbar.
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/pymc3/sampling.pyc in _iter_sample(draws, step, start, trace, chain, tune, model, random_seed)
#     650                 step = stop_tuning(step)
#     651             if step.generates_stats:
# --> 652                 point, states = step.step(point)
#     653                 if strace.supports_sampler_stats:
#     654                     strace.record(point, states)
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/pymc3/step_methods/arraystep.pyc in step(self, point)
#     220
#     221         if self.generates_stats:
# --> 222             apoint, stats = self.astep(array)
#     223             point = self._logp_dlogp_func.array_to_full_dict(apoint)
#     224             return point, stats
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/pymc3/step_methods/hmc/base_hmc.pyc in astep(self, q0)
#     115             self.potential.raise_ok()
#     116             raise ValueError('Bad initial energy: %s. The model '
# --> 117                              'might be misspecified.' % start.energy)
#     118
#     119         adapt_step = self.tune and self.adapt_step_size
#
# ValueError: Bad initial energy: inf. The model might be misspecified.

# %%
pm.traceplot(trace_logistic_model)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff1372d74d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff136f0e190>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff12e1996d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff136e1a050>]],
#       dtype=object)

# %%
TM,PM = bm.splitByFormula(formula,TDF,PDF['clean'])
# Out:
# INFO:external_plugins.spystats.biospytial_models.runner:Creating Design matrices from the formula LUCA ~ Longitude + Latitude + Q("Dist.to.road_m") + Population_m + name

# %%
model,gp = bm.ModelSamplingEffort(TM,PM)

# %%
trace = bm.SampleModel(model,inference_method='mcmc',ncores=3,niters=1200)
# Out:
# INFO:external_plugins.spystats.biospytial_models.runner:Selected inference method: MCMC  n_iters 1200, njobs 3
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# INFO:pymc3:Initializing NUTS using adapt_diag...
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# WARNING:theano.tensor.blas:We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# WARNING:theano.tensor.blas:We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# Sequential sampling (1 chains in 1 job)
# INFO:pymc3:Sequential sampling (1 chains in 1 job)
# NUTS: [latent_field, phi_log__, sigma_log__, tau_log__, b_name[T.uVEGETACI\xd3NSECUNDARIAARBUSTIVADEBOSQUEMES\xd3FILODEMONTA\xd1A], b_name[T.BOSQUEDEPINO], b_name[T.uVEGETACI\xd3NSECUNDARIAARB\xd3READEBOSQUEDEENCINO], b_name[T.PALMARINDUCIDO], b_Q(Dist.to.road_m), b_name[T.BOSQUEDEENCINO], b_name[T.uVEGETACI\xd3NSECUNDARIAARB\xd3READEBOSQUEDEPINO], b_name[T.uBOSQUEMES\xd3FILODEMONTA\xd1A], b_Population_m, b_name[T.uVEGETACI\xd3NSECUNDARIAARBUSTIVADEBOSQUEDEPINO-ENCINO], b_name[T.uVEGETACI\xd3NSECUNDARIAARB\xd3READEBOSQUEMES\xd3FILODEMONTA\xd1A], b_name[T.SELVAMEDIANASUBPERENNIFOLIA], b_name[T.uVEGETACI\xd3NSECUNDARIAARB\xd3READEBOSQUEDEPINO-ENCINO], b_name[T.uVEGETACI\xd3NSECUNDARIAARBUSTIVADESELVABAJACADUCIFOLIA], b_Longitude, b_name[T.AGRICULTURADETEMPORALANUAL], b_name[T.ASENTAMIENTOSHUMANOS], b_name[T.SELVABAJACADUCIFOLIA], b_Intercept, b_name[T.uVEGETACI\xd3NSECUNDARIAARB\xd3READESELVABAJACADUCIFOLIA], b_name[T.BOSQUEDEPINO-ENCINO], b_name[T.uVEGETACI\xd3NSECUNDARIAARBUSTIVADEBOSQUEDEENCINO], b_Latitude, b_name[T.PASTIZALINDUCIDO], b_name[T.PASTIZALCULTIVADO], b_name[T.uVEGETACI\xd3NSECUNDARIAARBUSTIVADEBOSQUEDEPINO], b_name[T.CUERPODEAGUA], b_name[T.uBOSQUEDET\xc1SCATE], b_name[T.AGRICULTURADETEMPORALANUALYPERMANENTE], b_name[T.BOSQUEDEENCINO-PINO]]
# INFO:pymc3:NUTS: [latent_field, phi_log__, sigma_log__, tau_log__, b_name[T.uVEGETACI\xd3NSECUNDARIAARBUSTIVADEBOSQUEMES\xd3FILODEMONTA\xd1A], b_name[T.BOSQUEDEPINO], b_name[T.uVEGETACI\xd3NSECUNDARIAARB\xd3READEBOSQUEDEENCINO], b_name[T.PALMARINDUCIDO], b_Q(Dist.to.road_m), b_name[T.BOSQUEDEENCINO], b_name[T.uVEGETACI\xd3NSECUNDARIAARB\xd3READEBOSQUEDEPINO], b_name[T.uBOSQUEMES\xd3FILODEMONTA\xd1A], b_Population_m, b_name[T.uVEGETACI\xd3NSECUNDARIAARBUSTIVADEBOSQUEDEPINO-ENCINO], b_name[T.uVEGETACI\xd3NSECUNDARIAARB\xd3READEBOSQUEMES\xd3FILODEMONTA\xd1A], b_name[T.SELVAMEDIANASUBPERENNIFOLIA], b_name[T.uVEGETACI\xd3NSECUNDARIAARB\xd3READEBOSQUEDEPINO-ENCINO], b_name[T.uVEGETACI\xd3NSECUNDARIAARBUSTIVADESELVABAJACADUCIFOLIA], b_Longitude, b_name[T.AGRICULTURADETEMPORALANUAL], b_name[T.ASENTAMIENTOSHUMANOS], b_name[T.SELVABAJACADUCIFOLIA], b_Intercept, b_name[T.uVEGETACI\xd3NSECUNDARIAARB\xd3READESELVABAJACADUCIFOLIA], b_name[T.BOSQUEDEPINO-ENCINO], b_name[T.uVEGETACI\xd3NSECUNDARIAARBUSTIVADEBOSQUEDEENCINO], b_Latitude, b_name[T.PASTIZALINDUCIDO], b_name[T.PASTIZALCULTIVADO], b_name[T.uVEGETACI\xd3NSECUNDARIAARBUSTIVADEBOSQUEDEPINO], b_name[T.CUERPODEAGUA], b_name[T.uBOSQUEDET\xc1SCATE], b_name[T.AGRICULTURADETEMPORALANUALYPERMANENTE], b_name[T.BOSQUEDEENCINO-PINO]]
#  64%|██████▍   | 1093/1700 [2:32:20<1:24:36,  8.36s/it]

# %%
import pymc3 as pm

# %%
 pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff5f77613d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff5f5af6c10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff5f5264e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff5f51c2450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff5f51b2c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff5f511b110>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff5f5094850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff5f50ba190>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff5f4ff8d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff5f4f05650>]],
#       dtype=object)

# %%
# %time pred_samples = bm.SamplePredictions(model,gp,TM,PM,trace)
# Out:
#   4%|▎         | 11/300 [01:19<34:51,  7.24s/it]

# %%
pred_samples['f_star'].shape
# Out:
# (300, 7475)

# %% [markdown]
# # Recreate the Raster Container
# Let's create the raster container.

# %%
from django.contrib.gis.geos import Point, Polygon
xcoord = -99.76
ycoord = 17.55
p = Point(xcoord,ycoord,srid=4326)
radii = np.linspace(0.08,1, 10)
polys = map(lambda r : p.buffer(r),radii)

# %%
from scipy import special as sp

alpha = sp.logit(0.8)
preds = pd.DataFrame(pred_samples['f_star']).transpose()
prob_gt05 = preds.apply(lambda row : float(sum(row > alpha))/len(row),axis=1)
mean_sample = preds.mean(axis=1)
q_025 = preds.quantile(0.025,axis=1)
q_975 = preds.quantile(0.975,axis=1)

surface_data = pd.DataFrame({'mean_sample' : mean_sample, 'q_025':q_025,'q_975':q_975,'p_ex50':prob_gt05})
#preds['idx'] = data_star.index.values
surface_data['idx'] = PDF['clean'].index.values
predictions = PDF['full'].merge(surface_data,how='left',left_index=True,right_on='idx',suffixes=('_obs','_pred'))

# %%
plt.scatter(predictions.Longitude,predictions.Latitude,c=predictions.mean_sample)

# %%
from raster_api.models import raster_models as models
from raster_api.tools import RasterData, RasterContainer
import utilities.data_extraction as de
from datapipelines import paper2 as p2
from ecoregions.models import TerrEcoregions,InegiIV
vectsel = [[TerrEcoregions,['wwf_mhtnum','wwf_mhtnam'],[np.nan,'NaN']],[InegiIV,['covid','name'],[np.nan,'NaN']]]
#polys = [polys[0]]

# %%
datasets = map(lambda polygon : de.compilePredictorRasterStack(polygon,100,100,models,as_dataframe=False),polys[:4])
# Out:
# INFO Alligning stacked raster data to common origin...
# INFO:biospytial.raster_api.tools:Alligning stacked raster data to common origin...
# INFO Alligning stacked raster data to common origin...
# INFO:biospytial.raster_api.tools:Alligning stacked raster data to common origin...
# INFO Alligning stacked raster data to common origin...
# INFO:biospytial.raster_api.tools:Alligning stacked raster data to common origin...
# INFO Alligning stacked raster data to common origin...
# INFO:biospytial.raster_api.tools:Alligning stacked raster data to common origin...

# %% [markdown]
# ## Examine covariates:
# These are:
#      * Distance to Road
#      * Population density
#      * vegetation type

# %%
population = polys3[8]
dist_2_road = polys3[9]
population.display_field(title='Population density')

# %%
dist_2_road.display_field(title='Distance to closest road')

# %%
polys3 = datasets[3]
elevation = polys3[0]
map_ = RasterContainer(predictions.mean_sample.values,exponential_fam='Bernoulli',use_metadata_from=datasets[3][0].rasterdata)
map_.display_field(band=2,origin='Lower',title='Mean latent field for sample effort')
#map_.exportToGeoTiff('sample_effort_p3')

# %%
polys3 = datasets[3]
elevation = polys3[0]
map_ = RasterContainer(predictions.p_ex50.values,exponential_fam='Bernoulli',use_metadata_from=datasets[3][0].rasterdata)
map_.display_field(band=2,origin='Lower',title='[sample effort-latent field] Exceeding prob. of more than 0.8' )
#map_.exportToGeoTiff('sample_effort_p3')

# %%
## Export to geotif to display in GIS
population.exportToGeoTiff('covariate-population-p3')
dist_2_road.exportToGeoTiff('covariate-dist-2-road-p3')
