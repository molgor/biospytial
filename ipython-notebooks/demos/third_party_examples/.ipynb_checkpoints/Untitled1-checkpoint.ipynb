# %%
# %matplotlib inline
import sys
sys.path.append('/apps')
import django
django.setup()

# %%
import GPflow as gf

# %%
from external_plugins.spystats.models import *

# %%
lat
# Out:
# array([   0.        ,   11.11111111,   22.22222222,   33.33333333,
#          44.44444444,   55.55555556,   66.66666667,   77.77777778,
#          88.88888889,  100.        ])

# %%
points
# Out:
# [array([ 0.,  0.]),
#  array([  0.        ,  11.11111111]),
#  array([  0.        ,  22.22222222]),
#  array([  0.        ,  33.33333333]),
#  array([  0.        ,  44.44444444]),
#  array([  0.        ,  55.55555556]),
#  array([  0.        ,  66.66666667]),
#  array([  0.        ,  77.77777778]),
#  array([  0.        ,  88.88888889]),
#  array([   0.,  100.]),
#  array([ 11.11111111,   0.        ]),
#  array([ 11.11111111,  11.11111111]),
#  array([ 11.11111111,  22.22222222]),
#  array([ 11.11111111,  33.33333333]),
#  array([ 11.11111111,  44.44444444]),
#  array([ 11.11111111,  55.55555556]),
#  array([ 11.11111111,  66.66666667]),
#  array([ 11.11111111,  77.77777778]),
#  array([ 11.11111111,  88.88888889]),
#  array([  11.11111111,  100.        ]),
#  array([ 22.22222222,   0.        ]),
#  array([ 22.22222222,  11.11111111]),
#  array([ 22.22222222,  22.22222222]),
#  array([ 22.22222222,  33.33333333]),
#  array([ 22.22222222,  44.44444444]),
# ...
