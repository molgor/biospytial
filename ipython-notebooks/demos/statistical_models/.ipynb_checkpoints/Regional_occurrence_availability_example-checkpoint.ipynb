# %% [markdown]
# # How many data out there?
# We will retrieve all the cells at lower resolution. Check if they have data (children) and then convert it to raster ("not take much time on this).
#
# ## Later
# In this exercise I'll perform a spatial autocorrelation model using the tools available in spystats and the data stored in *Biospytial*
# In particular estimate a richness model.

# %%
# %matplotlib inline
import sys
sys.path.append('/apps')
import django
django.setup()
from drivers.tree_builder import TreeNeo
from drivers.graph_models import TreeNode, Order, Family, graph
from drivers.graph_models import Cell,Mex4km, countObjectsOf

# %% [markdown]
# ## Take a subsample of the Cells.

# %%
n = graph.data("MATCH (n:mex4km) RETURN Count(n)").pop()['Count(n)']

# %%
n = countObjectsOf(Mex4km)
print(n)
# Out:
# 279277

# %% [markdown]
# ### A lot of data we need to use a sampling method.

# %%
import numpy as np
sample_size = 1000
choices = np.random.choice(range(1,n),sample_size,replace='False')

# %% [markdown]
# ### Query for exporting a selection of cells.

# %%
c = list(choices)
sel = Mex4km.select(graph).where("_.id IN  %s "%str(c))

# %%
# %time samples = list(sel)
# Out:
# CPU times: user 1.59 s, sys: 36 ms, total: 1.63 s
# Wall time: 1.83 s

# %%
connections_to = map(lambda s : list(s.connected_to),samples)

# %%
import drivers.tree_builder as tb

# %%
# %time trees = map(lambda cell : tb.buildTreeNeo(cell),samples)
# Out:
# CPU times: user 1min 52s, sys: 4.4 s, total: 1min 56s
# Wall time: 2min 50s

# %%
big_tree = reduce(lambda a,b : a+b , trees)
# Out:
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees
# INFO Merging Trees

# %%
tl.plotTree(tt)

# %%
import traversals.strategies as strg

# %%
type(root)
# Out:
# drivers.tree_builder.LocalTree

# %%
root = t.node

# %%
a = strg.getPresencesForNode(root,trees)

# %%
data_t = strg.getPresencesForListOfNodes([root],trees)

# %%
data_t
# Out:
#      LUCA   Longitude  Latitude
# 0     1.0 -112.351563  29.01339
# 1     0.0 -103.384563  39.45039
# 2     0.0  -92.261563  32.05139
# 3     0.0 -104.805563  42.97839
# 4     0.0 -103.482563  38.96039
# 5     0.0  -85.695563  32.29639
# 6     0.0 -103.972563  28.08239
# 7     1.0  -96.034563  17.10639
# 8     0.0 -108.872563  37.39239
# 9     0.0  -90.105563  39.59739
# 10    1.0  -93.731563  17.05739
# 11    0.0  -95.642563  38.37239
# 12    0.0 -108.333563  32.24739
# 13    0.0  -96.181563  29.50339
# 14    0.0 -101.865563  24.99539
# 15    0.0  -89.713563  37.04939
# 16    0.0 -100.395563  43.56639
# 17    0.0  -89.468563  16.07739
# 18    0.0  -92.114563  34.79539
# 19    1.0  -97.504563  25.87739
# 20    0.0  -95.348563  42.88039
# 21    0.0  -90.791563  35.33439
# 22    0.0  -81.677563  36.51039
# 23    1.0  -96.279563  15.88139
# 24    0.0  -93.878563  32.98239
# 25    0.0 -108.823563  25.92639
# 26    0.0  -98.729563  22.93739
# 27    0.0 -102.894563  41.99839
# 28    0.0 -110.685563  36.55939
# 29    0.0  -86.724563  30.97339
# ..    ...         ...       ...
# 965   0.0  -94.417563  41.65539
# 966   0.0  -83.098563  29.35639
# 967   0.0  -89.566563  33.03139
# 968   0.0  -95.691563  32.54139
# 969   0.0  -82.608563  33.08039
# 970   0.0 -106.030563  29.06239
# 971   0.0 -114.556563  34.99139
# 972   0.0  -98.190563  27.00439
# 973   1.0  -98.092563  17.59639
# 974   0.0 -100.101563  29.01339
# 975   0.0 -106.471563  37.93139
# 976   0.0 -115.291563  29.94439
# 977   0.0 -111.910563  32.93339
# 978   0.0 -100.983563  40.08739
# 979   0.0  -85.450563  34.25639
# 980   0.0  -81.187563  26.07339
# 981   0.0  -96.573563  34.20739
# 982   0.0 -104.217563  27.83739
# 983   0.0  -90.497563  32.93339
# 984   0.0 -104.168563  42.43939
# 985   1.0 -101.718563  23.32939
# 986   1.0 -108.578563  27.34739
# 987   1.0  -99.660563  22.83939
# 988   1.0  -91.526563  17.44939
# 989   1.0  -98.582563  18.18439
# 990   0.0  -88.047563  35.18739
# 991   0.0  -88.831563  38.32339
# 992   0.0 -104.413563  22.74139
# 993   0.0 -101.179563  43.76239
# 994   0.0  -84.029563  31.26739
#
# [995 rows x 3 columns]

# %% [markdown]
# # The model

# %%
import pymc3 as pm

# %%
## Analysis, GP only one parameter to fit
# The variational method is much beter.
from pymc3.variational.callbacks import CheckParametersConvergence

with pm.Model() as model:
    #sigma=3.5
    #range_a=10.13
    
    
    sigma = pm.Uniform('sigma',0,4)
    #phi = pm.HalfNormal('phi',mu=8,sd=3)
    #phi = pm.Uniform('phi',6,12)
    phi = pm.Uniform('phi',5,15)
    cov = sigma * pm.gp.cov.Matern32(2,phi,active_dims=[0,1])
    #K = cov(grid[['Lon','Lat']].values)
    #phiprint = tt.printing.Print('phi')(phi)
    
    ## The latent function
    gp = pm.gp.Latent(cov_func=cov)
    
    ## I don't know why this
    f = gp.prior("latent_field", X=data_t[['Longitude','Latitude']].values,reparameterize=True)
    
    #f_print = tt.printing.Print('latent_field')(f)
    
    y_obs = pm.Poisson('y_obs',mu=f,observed=data_t.LUCA)
    
    #y_obs = pm.MvNormal('y_obs',mu=np.zeros(n*n),cov=K,observed=grid.Z)
    
    #gp = pm.gp.Latent(cov_func=cov,observed=sample)
    # Use elliptical slice sampling
    #ess_step = pm.EllipticalSlice(vars=[f_sample], prior_cov=K)
    #step = pm.HamiltonianMC()
    #step = pm.Metropolis()
    #%time trace = pm.sample(5000,step)#,tune=0,chains=1)
    ## Variational
    
    # %time mean_field = pm.fit(method='advi', callbacks=[CheckParametersConvergence()])
# Out:
# Average Loss = inf:   2%|▏         | 157/10000 [00:32<33:27,  4.90it/s]

# %%
ts = trees[:10]

# %%
getdata = lambda tree : tree.associatedData.getEnvironmentalVariablesCells()

# %%
ts[1].associatedData.getEnvironmentalVariablesCells()
# Out:
# ERROR Could not extract Raster data from aggregation
# ERROR:biospytial.raster_api.tools:Could not extract Raster data from aggregation
# Exception django.contrib.gis.gdal.error.GDALException: GDALException('Invalid pointer returned from "GDALClose"',) in ERROR Could not extract Raster data from aggregation
# ERROR:biospytial.raster_api.tools:Could not extract Raster data from aggregation
# Exception django.contrib.gis.gdal.error.GDALException: GDALException('Invalid pointer returned from "GDALClose"',) in ERROR Could not extract Raster data from aggregation
# ERROR:biospytial.raster_api.tools:Could not extract Raster data from aggregation
# Exception django.contrib.gis.gdal.error.GDALException: GDALException('Invalid pointer returned from "GDALClose"',) in ERROR Could not extract Raster data from aggregation
# ERROR:biospytial.raster_api.tools:Could not extract Raster data from aggregation
# Exception django.contrib.gis.gdal.error.GDALException: GDALException('Invalid pointer returned from "GDALClose"',) in
# {'Elevation_mean': 1595.6666666666667,
#  'MaxTemperature_mean': 17.209027858795945,
#  'MeanTemperature_mean': 'N.A.',
#  'MinTemperature_mean': 'N.A.',
#  'Precipitation_mean': 32.541666666666664,
#  'SolarRadiation_mean': 16641.82638888889,
#  'Vapor_mean': 'N.A.',
#  'WindSpeed_mean': 'N.A.'}

# %%
list(choices)
# Out:
# [42719,
#  172297,
#  52525,
#  246197,
#  42383,
#  109712,
#  259053,
#  154123,
#  241544,
#  124495,
#  5561,
#  60762,
#  120534,
#  255395,
#  173259,
#  131683,
#  121997,
#  218954,
#  191613,
#  238116,
#  94060,
#  73565,
#  166272,
#  12589,
#  185400,
#  195762,
#  18574,
#  194492,
#  19841,
#  126756,
#  194355,
#  224429,
#  95495,
#  76028,
#  258961,
#  159167,
#  139759,
#  145833,
#  15188,
#  16047]

# %%
n
