# %%
#Loading things as usual
#%matplotlib inline
import sys
sys.path.append('/apps')
import django
django.setup()

import matplotlib.pyplot as plt
import pandas as pd
import itertools as it
import numpy as np
import pymc3 as pm

## Use the ggplot style
plt.style.use('ggplot')

# %%
with pm.Model() as model:
    mu = pm.Normal('mu',mu=0,sd=1)
    obs = pm.Normal('x', mu=mu, sd=1, observed=np.random.randn(100))

# %%
with model:
    sample = pm.sample(draws=1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [mu]
# 100%|██████████| 1500/1500 [00:00<00:00, 2063.80it/s]

# %%
pm.traceplot(sample)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4906fdbd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4949fb0590>]], dtype=object)

# %%
import scipy.stats as st

# %%
x = np.linspace(-100,100,100)

# %%
a = st.binom.rvs(k=range(10),n=10,p=0.6,size=100)
#a = st.norm.pdf(x,loc=0,scale=10)
b = st.norm.pdf(x,loc=0,scale=1)

#c = a*b
c = a
plt.plot(c)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-60-c6b8f841c884> in <module>()
# ----> 1 a = st.binom.rvs(k=range(10),n=10,p=0.6,size=100)
#       2 #a = st.norm.pdf(x,loc=0,scale=10)
#       3 b = st.norm.pdf(x,loc=0,scale=1)
#       4
#       5 #c = a*b
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.pyc in rvs(self, *args, **kwargs)
#    2807         """
#    2808         kwargs['discrete'] = True
# -> 2809         return super(rv_discrete, self).rvs(*args, **kwargs)
#    2810
#    2811     def pmf(self, k, *args, **kwds):
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.pyc in rvs(self, *args, **kwds)
#     935         discrete = kwds.pop('discrete', None)
#     936         rndm = kwds.pop('random_state', None)
# --> 937         args, loc, scale, size = self._parse_args_rvs(*args, **kwds)
#     938         cond = logical_and(self._argcheck(*args), (scale >= 0))
# ...

# %%
a
# Out:
# 0.04246732800000004

# %%
st.binom?
# Out:
# Signature:       st.binom(self, *args, **kwds)
# Call signature:  st.binom(*args, **kwds)
# Type:            binom_gen
# String form:     <scipy.stats._discrete_distns.binom_gen object at 0x7f491e3ce110>
# File:            /opt/conda/envs/biospytial/lib/python2.7/site-packages/scipy/stats/_discrete_distns.py
# Docstring:
# A binomial discrete random variable.
#
# As an instance of the `rv_discrete` class, `binom` object inherits from it
# a collection of generic methods (see below for the full list),
# and completes them with details specific for this particular distribution.
#
# Methods
# -------
# rvs(n, p, loc=0, size=1, random_state=None)
#     Random variates.
# pmf(k, n, p, loc=0)
#     Probability mass function.
# logpmf(k, n, p, loc=0)
#     Log of the probability mass function.
# cdf(k, n, p, loc=0)
#     Cumulative distribution function.
# logcdf(k, n, p, loc=0)
#     Log of the cumulative distribution function.
# sf(k, n, p, loc=0)
# ...
