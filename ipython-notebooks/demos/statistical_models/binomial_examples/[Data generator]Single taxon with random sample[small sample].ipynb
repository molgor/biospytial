# %% [markdown]
# # Obtaining random cell samples
# In this exercise we will obtain a random sample of cells with its associate environmental covariates.

# %%
# %matplotlib inline
import sys
sys.path.append('/apps')
import django
django.setup()
from drivers.tree_builder import TreeNeo
from drivers.graph_models import TreeNode, Order, Family, graph,Kingdom,Occurrence
from drivers.graph_models import Cell,Mex4km, countObjectsOf
from drivers.graph_models import pickNode
import matplotlib.pyplot as plt
import pandas as pd
import itertools as it
import numpy as np

## Use the ggplot style
plt.style.use('ggplot')

# %% [markdown]
# 2. Selecting the space of considered cells.
# For this case we will consider all the Mexican Territory. We can load the Mexican polygon from the database with the following commands.
#
# > Failing to do so will likely obtain all the registered cells. In cases could hang the system.

# %%
from sketches.models import Country
from mesh.models import MexMesh
from traversals.sampling import UniformRandomCellSample

Mexico = Country.objects.filter(name__contains="exico").get()
mexican_cells = MexMesh.objects.filter(cell__intersects=Mexico.geom)

# %%
# Get all cell ids
ids = list(mexican_cells.values('pk'))
CellNodeClass = Mex4km
list_of_cell_ids = ids
sample_size = 300
selection_of_cells = UniformRandomCellSample(ids,Mex4km,sample_size=sample_size,random_seed=12345,with_replacement=True)
# Out:
# INFO Using custom random seed of: 12345
# INFO Compiling Query and asking the Graph Database

# %% [markdown]
# The size of 'ids' is {{n}}
# 3. Generate the trees for each cell.

# %%
# %time cells = list(selection_of_cells)
# Out:
# CPU times: user 1.93 s, sys: 96 ms, total: 2.03 s
# Wall time: 5.4 s

# %% [markdown]
# 1.2 We will use the function *buildTreeNeo* to extract the taxonomic tree in that area.

# %%
from traversals import strategies as st
# %time trees = map(lambda cell : st.buildTreeNeo(cell),cells)
# Out:
# CPU times: user 42.5 s, sys: 1.41 s, total: 43.9 s
# Wall time: 47.4 s

# %% [markdown]
# ## Union of trees

# %%
# %time ocs = reduce(lambda a,b : a + b ,map(lambda t : t.occurrences, trees))
# Out:
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 11.1 ms

# %%
## Ohh! super fast (compared to the other method that takes more than 20 minutes for this sample size)
# %time bigtree = TreeNeo(ocs,cell_objects=cells)
# Out:
# CPU times: user 408 ms, sys: 12 ms, total: 420 ms
# Wall time: 421 ms

# %%
## Extract the root (if any!)
root = bigtree.to_Plantae

# %%
root
# Out:
# <LocalTree | Kingdom: Plantae - n.count : 1700- | AF: 0.05 >

# %%
## Get presences absences
def PresenceAbsence(node,list_of_trees):
    pres_reps = pd.DataFrame({
    'Y' : map(
        lambda tree : tree.hasNode(node),list_of_trees)
    }).astype('int')
    return pres_reps

# %%
pres = PresenceAbsence(root,trees)

# %%
sum(pres.values)
# Out:
# array([112])

# %%
vars=['Elevation', 'MaxTemperature', 'MeanTemperature',
      'MinTemperature', 'Precipitation', 'Vapor',
      'SolarRadiation', 'WindSpeed','WorldPopLatam2010','DistanceToRoadMex' ]
#st.getEnvironmentalCovariatesFromListOfCells(cells,vars)

# %% [markdown]
# ## Get environmental Covariates

# %%
from traversals import strategies as st

# %time data = st.getEnvironmentalCovariatesFromListOfCells(cells,vars=vars)
# Out:
# CPU times: user 6.58 s, sys: 108 ms, total: 6.68 s
# Wall time: 1min 42s

# %% [markdown]
# ### Concatenate two dataframes
# > Build some utility functions for automating this tasks

# %%
data
# Out:
#      DistanceToRoadMex_mean  Elevation_mean  MaxTemperature_mean  \
# 0               3868.661519       63.222222            30.225231
# 1               1379.938936        3.888889            27.693981
# 2               9728.652812     2353.000000            21.844722
# 3               2510.775420     1305.777778            27.772222
# 4               4264.779688     1212.777778            26.811343
# 5               9601.187188      283.444444            30.418518
# 6               4325.744238       59.555556            29.541945
# 7               7029.830352      108.555556            32.506019
# 8               1235.716885     2240.333333            22.721111
# 9               1906.436431      174.111111            28.574537
# 10              4665.098877     1603.111111            25.656250
# 11              4143.240698      271.250000            31.701620
# 12             23043.572344     1211.666667            26.597222
# 13              9351.246777      815.888889            32.228935
# 14             19559.793125      216.166667            29.732407
# 15             12511.519961      136.777778            30.578241
# 16               988.591069     1726.444444            27.528056
# 17              1874.697153     1346.555556            27.888426
# 18               800.000000       22.666667            32.181018
# 19              4412.895352     1710.888889            25.180556
# 20              4970.685449     1799.888889            27.013194
# 21              5858.670898     1356.444444            28.286111
# 22              1365.247241     1343.444444            27.292824
# 23              1915.500947     2560.555556            21.563194
# 24              7401.018496     1169.000000            24.919444
# 25              8904.326816        1.666667            31.868611
# 26             11679.256016        6.777778            30.416667
# 27              3746.718164     2826.500000            16.629398
# 28              1666.436431      406.444444            29.409954
# 29              4467.204980      228.444444            32.415046
# ..                      ...             ...                  ...
# 269             5104.230010      607.777778            28.568519
# 270             5596.836003        7.333333            30.959722
# 271             3412.961755      406.555556            29.970139
# 272             3644.051812     1267.333333            27.950833
# 273             1195.716885      650.888889            28.196111
# 274             8707.200228     1481.777778            29.947685
# 275             8109.391289       83.777778            30.463657
# 276             1275.716885       31.555556            30.175926
# 277             4556.439648      389.111111            31.473333
# 278             1042.579805      187.777778            31.184491
# 279             2258.113506     2347.555556            19.939722
# 280             1949.571436     2040.222222            23.846528
# 281             5159.661162      267.000000            29.418055
# 282             5312.214307      392.444444            29.449722
# 283             2800.364303     1618.222222            26.253009
# 284             9702.614062      961.222222            29.339352
# 285             1948.239941      526.444444            29.212222
# 286             1529.861499     1072.222222            29.531944
# 287             1382.146924     1595.888889            25.246065
# 288             4963.185908     2192.000000            23.144213
# 289             1400.000000     2136.500000            22.945602
# 290             1879.533240      169.444444            29.676157
# 291             5890.914071     2265.333333            22.061111
# 292             6035.303574       18.111111            33.760185
# 293             1714.083550      467.333333            32.770834
# 294             1151.433770      756.000000            32.755000
# 295            11496.329362        7.444444            32.432176
# 296             3899.039302     2260.444444            23.924306
# 297             2674.255398     1482.777778            26.545833
# 11   -95.299563  16.61639
# 12  -106.814563  31.41439
# 13   -99.023563  17.89039
# 14  -113.233563  27.78839
# 15  -112.939563  26.90639
# 16  -100.787563  23.86839
# 17  -103.580563  19.40939
# 18  -112.988563  30.87539
# 19  -101.032563  22.59439
# 20  -101.032563  23.62339
# 21   -99.709563  21.02639
# 22  -104.021563  28.52339
# 23  -106.471563  26.26939
# 24   -98.288563  20.48739
# 25   -92.163563  18.42939
# 26  -113.331563  26.90639
# 27   -96.475563  17.40039
# 28  -101.277563  27.15139
# 29  -107.941563  25.63239
# ..          ...       ...
# 269 -101.277563  28.42539
# 270  -95.985563  18.82139
# 271  -99.415563  22.83939
# 272  -99.954563  21.51639
# 273 -100.346563  26.22039
# 274  -98.092563  17.69439
# 275  -95.152563  17.49839
# 276  -98.043563  22.49639
# 277 -110.979563  28.57239
# 278 -112.498563  30.43439
# 279 -106.520563  25.19139
# 280  -97.210563  17.15539
# 281 -100.493563  27.15139
# 282  -98.925563  22.10439
# 283  -96.818563  16.37139
# 284 -102.257563  18.47839
# 285 -101.522563  27.00439
# 286 -102.747563  28.71939
# 287 -106.373563  29.16039
# 288 -106.961563  28.86639
# 289  -96.916563  17.05739
# 290  -98.778563  25.82839
# 291  -97.357563  17.44939
# 292  -92.457563  14.99939
# 293 -110.342563  29.35639
# 294 -101.081563  18.87039
# 295  -91.673563  18.13539
# 296 -103.482563  22.69239
# 297  -98.778563  20.78139
# 298 -111.714563  25.68139
#
# [299 rows x 12 columns]

# %%
training_data = pd.concat([pres,data],axis=1)

# %% [markdown]
# ## Extract vector information (Too be implemented soon!)

# %%
points = map(lambda c : c.centroid, cells)

# %%
from ecoregions.models import TerrEcoregions,InegiIV
ecoregions = map(lambda p : TerrEcoregions.objects.filter(geom__intersects=p),points)
ecovalues = map(lambda q : q.values_list('wwf_mhtnum','wwf_mhtnam'),ecoregions)

# %%
ecovals = [r.get() if r.exists() else (np.nan,np.nan) for r in ecovalues ]

# %%
vegdat = pd.DataFrame(ecovals)
vegdat.columns = ['vegid','vegname']

# %%
vegdat
# Out:
#      vegid                                            vegname
# 0       13                       Deserts and Xeric Shrublands
# 1        7  Tropical and Subtropical Grasslands, Savannas ...
# 2        3        Tropical and Subtropical Coniferous Forests
# 3        3        Tropical and Subtropical Coniferous Forests
# 4       13                       Deserts and Xeric Shrublands
# 5       13                       Deserts and Xeric Shrublands
# 6       13                       Deserts and Xeric Shrublands
# 7        2     Tropical and Subtropical Dry Broadleaf Forests
# 8       13                       Deserts and Xeric Shrublands
# 9       13                       Deserts and Xeric Shrublands
# 10       3        Tropical and Subtropical Coniferous Forests
# 11       2     Tropical and Subtropical Dry Broadleaf Forests
# 12      13                       Deserts and Xeric Shrublands
# 13       2     Tropical and Subtropical Dry Broadleaf Forests
# 14      13                       Deserts and Xeric Shrublands
# 15      13                       Deserts and Xeric Shrublands
# 16      13                       Deserts and Xeric Shrublands
# 17       2     Tropical and Subtropical Dry Broadleaf Forests
# 18      13                       Deserts and Xeric Shrublands
# 19      13                       Deserts and Xeric Shrublands
# 20      13                       Deserts and Xeric Shrublands
# 21      13                       Deserts and Xeric Shrublands
# 22      13                       Deserts and Xeric Shrublands
# 23       3        Tropical and Subtropical Coniferous Forests
# 24       1   Tropical and Subtropical Moist Broadleaf Forests
# 25       1   Tropical and Subtropical Moist Broadleaf Forests
# 26      13                       Deserts and Xeric Shrublands
# 27       3        Tropical and Subtropical Coniferous Forests
# 28      13                       Deserts and Xeric Shrublands
# 29       2     Tropical and Subtropical Dry Broadleaf Forests
# ..     ...                                                ...
# 269     13                       Deserts and Xeric Shrublands
# 270      1   Tropical and Subtropical Moist Broadleaf Forests
# 271      1   Tropical and Subtropical Moist Broadleaf Forests
# 272     13                       Deserts and Xeric Shrublands
# 273     13                       Deserts and Xeric Shrublands
# 274      3        Tropical and Subtropical Coniferous Forests
# 275      1   Tropical and Subtropical Moist Broadleaf Forests
# 276      1   Tropical and Subtropical Moist Broadleaf Forests
# 277     13                       Deserts and Xeric Shrublands
# 278     13                       Deserts and Xeric Shrublands
# 279      3        Tropical and Subtropical Coniferous Forests
# 280      2     Tropical and Subtropical Dry Broadleaf Forests
# 281     13                       Deserts and Xeric Shrublands
# 282      1   Tropical and Subtropical Moist Broadleaf Forests
# 283      3        Tropical and Subtropical Coniferous Forests
# 284      2     Tropical and Subtropical Dry Broadleaf Forests
# 285     13                       Deserts and Xeric Shrublands
# 286     13                       Deserts and Xeric Shrublands
# 287     13                       Deserts and Xeric Shrublands
# 288     13                       Deserts and Xeric Shrublands
# 289      3        Tropical and Subtropical Coniferous Forests
# 290     13                       Deserts and Xeric Shrublands
# 291      3        Tropical and Subtropical Coniferous Forests
# 292      2     Tropical and Subtropical Dry Broadleaf Forests
# 293     13                       Deserts and Xeric Shrublands
# 294      2     Tropical and Subtropical Dry Broadleaf Forests
# 295      1   Tropical and Subtropical Moist Broadleaf Forests
# 296      3        Tropical and Subtropical Coniferous Forests
# 297      1   Tropical and Subtropical Moist Broadleaf Forests
# 298     13                       Deserts and Xeric Shrublands
#
# [299 rows x 2 columns]

# %%
training_data = pd.concat([training_data,vegdat],axis=1)

# %% [markdown]
# ## Let's save this for the moment

# %%
#training_data.to_csv("/outputs/root_train_with_pop_lc.csv")

# %%
training_data[:5]
# Out:
#    Y  DistanceToRoadMex_mean  Elevation_mean  MaxTemperature_mean  \
# 0  0             3868.661519       63.222222            30.225231
# 1  0             1379.938936        3.888889            27.693981
# 2  1             9728.652812     2353.000000            21.844722
# 3  0             2510.775420     1305.777778            27.772222
# 4  0             4264.779688     1212.777778            26.811343
#
#   MeanTemperature_mean MinTemperature_mean  Precipitation_mean  \
# 0              20.7662             30.3171            7.560185
# 1              23.0694             27.8079           58.791667
# 2              13.7833             21.8806           47.480556
# 3               20.794              27.831           85.865741
# 4                 N.A.                N.A.           19.287037
#
#    SolarRadiation_mean Vapor_mean WindSpeed_mean WorldPopLatam2010_mean  \
# 0         18867.312500       1.75        2.26389                2.71775
# 1         16915.250000    2.21296        4.41667                3.72007
# 2         18051.152778          1        3.11389                3.48854
# 3         18112.976852    1.30093        2.18519                 2.5483
# 4         19742.972222       N.A.           N.A.                   N.A.
#
#     Longitude  Latitude  vegid  \
# 0 -113.380563  27.54339     13
# 1  -97.406563  25.68139      7
# 2 -103.629563  22.83939      3
# 3 -107.255563  25.97539      3
# 4 -107.500563  31.80639     13
#
#                                              vegname
# 0                       Deserts and Xeric Shrublands
# 1  Tropical and Subtropical Grasslands, Savannas ...
# 2        Tropical and Subtropical Coniferous Forests
# 3        Tropical and Subtropical Coniferous Forests
# 4                       Deserts and Xeric Shrublands

# %%
## Save it / store it:
training_data.to_csv("/outputs/training_dataset_complete_with_socioeconomical.csv")

# %%
points = map(lambda c : c.centroid,cells)

# %%
c = cells[0]

# %%
c.srid
# Out:
# 4326

# %%
c.centroid??
# Out:
# Type:        property
# String form: <property object at 0x7f85e5005ec0>
# Source:
# # c.centroid.fget
# @property
# def centroid(self):
#     pointstr = 'POINT(%s %s)'%(self.longitude,self.latitude)
#     point = GEOSGeometry(pointstr,srid=self.srid)
#     return point

# %%
## Put srid to all centroids
#map(lambda p : p.set_srid(4326),points)

# %%
p = points[0]

# %%
## Convert to Point geometry
from django.contrib.gis.geos import  GEOSGeometry
fx = lambda arr :'POINT(%s %s)'%(arr[0],arr[1])
points = map(lambda p : GEOSGeometry(p,srid=4326), map(fx,cc))

# %%
from django.contrib.gis.db.models.functions import Distance
from django.contrib.gis.measure import D

# %%
## Import roads
from sketches.models import MexRoads

# %%
q = MexRoads.objects.filter(geom__distance_lte=(p,D(m=30000)))

# %%
q
# Out:
# <QuerySet [<MexRoads: <Road Layer instance: 0.0 >>, <MexRoads: <Road Layer instance: 0.0 >>, <MexRoads: <Road Layer instance: 0.0 >>]>

# %%
print(q)
# Out:
# SELECT "public"."mexroads"."gid", "public"."mexroads"."gid", "public"."mexroads"."tnode_", "public"."mexroads"."lpoly_", "public"."mexroads"."rpoly_", "public"."mexroads"."length", "public"."mexroads"."cov_", "public"."mexroads"."cov_id", "public"."mexroads"."geom" FROM "public"."mexroads" WHERE ST_DWithin("public"."mexroads"."geom", ST_GeomFromEWKB('\001\001\000\000 \346\020\000\000\212q\250&[X\\\300cF\020\230\033\213;@'::bytea), 1)

# %%
## Let's calculate distance
>>> from django.contrib.gis.db.models.functions import Distance
>>> pnt = AustraliaCity.objects.get(name='Hobart').point
>>> for city in AustraliaCity.objects.annotate(distance=Distance('point', pnt)):
...     print(city.name, city.distance)
Wollongong 990071.220408 m
Shellharbour 972804.613941 m
Thirroul 1002334.36351 m
...
