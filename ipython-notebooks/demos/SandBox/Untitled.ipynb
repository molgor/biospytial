# %% [markdown]
# ## Un primer pinche prueba con R en jupyter en mi ambiente de docker de biospytial

# %%
hist(rnorm(100,10,2))
# Out:
# Plot with title “Histogram of rnorm(100, 10, 2)”

# %% [markdown]
# $$y = 9933$$

# %%
library(lattice)
mat = matrix(rnorm(10000), 100)
levelplot(mat)
# Out:
# plot without title

# %% [markdown]
# $$y=00$$

# %% [markdown]
# $y=44$

# %% [markdown]
# $Y=33$

# %% [markdown]
# Yes is very important to Write
# $G(x,y) = Sin(\alpha)$
