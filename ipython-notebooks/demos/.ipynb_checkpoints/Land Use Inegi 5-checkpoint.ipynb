# %% [markdown]
# ## Initialize environment

# %%
# %matplotlib inline
import sys
sys.path.append('/apps')
import django
django.setup()
from drivers.tree_builder import TreeNeo
from drivers.graph_models import TreeNode, Order, Family, graph

# %% [markdown]
# ### Load bursera family node

# %%
bursera = list(Family.select(graph).where("_.name=~'Burser.*'")).pop()

# %% [markdown]
# Get the cells in all the country

# %%
# %time cells = list(bursera.cells)
# Out:
# CPU times: user 5.32 s, sys: 80 ms, total: 5.4 s
# Wall time: 5.65 s

# %%
cells
# Out:
# [<Cell id=249056>,
#  <Cell id=158351>,
#  <Cell id=249055>,
#  <Cell id=218569>,
#  <Cell id=238213>,
#  <Cell id=243529>,
#  <Cell id=248946>,
#  <Cell id=218563>,
#  <Cell id=249372>,
#  <Cell id=233708>,
#  <Cell id=250646>,
#  <Cell id=235098>,
#  <Cell id=252093>,
#  <Cell id=257088>,
#  <Cell id=249368>,
#  <Cell id=249369>,
#  <Cell id=235099>,
#  <Cell id=249760>,
#  <Cell id=250311>,
#  <Cell id=250313>,
#  <Cell id=250316>,
#  <Cell id=250315>,
#  <Cell id=249759>,
#  <Cell id=253181>,
#  <Cell id=261715>,
#  <Cell id=261710>,
#  <Cell id=261708>,
#  <Cell id=261709>,
#  <Cell id=261706>,
#  <Cell id=261707>,
#  <Cell id=249631>,
#  <Cell id=222902>,
#  <Cell id=243795>,
#  <Cell id=223484>,
#  <Cell id=240712>,
#  <Cell id=220920>,
#  <Cell id=253444>,
#  <Cell id=242485>,
#  <Cell id=260459>,
#  <Cell id=260458>,
#  <Cell id=222826>,
#  <Cell id=214058>,
#  <Cell id=260455>,
#  <Cell id=260454>,
#  <Cell id=260453>,
#  <Cell id=260452>,
#  <Cell id=245912>,
# ...

# %%
c1 = cells[1]

# %%
import itertools as it

# %%
upcells = it.imap(lambda cell : list(cell.upperCell)[0], bursera.cells)

# %%
getUpperCells = lambda list_of_cells : set(it.imap(lambda cell : list(cell.upperCell)[0],list_of_cells))

# %%
tod = reduce(lambda c1,c2 : c1 + c2 ,upcells)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-30-18ef7f3265a7> in <module>()
# ----> 1 tod = reduce(lambda c1,c2 : c1 + c2 ,upcells)
#
# <ipython-input-30-18ef7f3265a7> in <lambda>(c1, c2)
# ----> 1 tod = reduce(lambda c1,c2 : c1 + c2 ,upcells)
#
# TypeError: unsupported operand type(s) for +: 'Cell' and 'Cell'

# %%
tams = [2232, 1555, 904, 411, 167, 60, 24, 9, 3, 3]

# %%
import matplotlib.pyplot as plt
plt.plot(tams)

# %%
len(upc)
# Out:
# 2537

# %%
lx = [1.0
    0.8797792668506109,
 0.6966845878136201,
 0.5813504823151125,
 0.45464601769911506,
 0.40632603406326034,
 0.3592814371257485,
 0.4,
 0.375,
 0.3333333333333333,
 0.3333333333333333]

# %%
plt.plot(lx)
