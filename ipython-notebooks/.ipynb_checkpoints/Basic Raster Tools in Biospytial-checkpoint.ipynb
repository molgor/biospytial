# %%
import sys
sys.path.append('/home/juan/git-projects/biospytial')

# %% [markdown]
# * I don't know why but I need to explicitly append the modules path to the environment library path.

# %% [markdown]
# * Reload django setup

# %%
## Load the custom spatial lookup

# %%
import django
django.setup()

# %%
# %matplotlib notebook

# %% [markdown]
# # Basic Raster Tools
#
# In this section we will review the process for generating raster cells, visualize them and export them as Geotif.

# %% [markdown]
# ## How to create a polygon compatible with geospatial ?
# 1 . First we'll need a WKT representation of the polygon we want to parse.

# %%
polystr = "POLYGON((-109 27,-106 27,-106 30,-109 30,-109 27))"

# %% [markdown]
# * Because the data models are in WGS84 the standard coordinate system will be the same, therefore it's not important to define an SRID now.

# %% [markdown]
# Let's import the library for handling this:

# %%
from django.contrib.gis.geos import GEOSGeometry

# %%
polygon = GEOSGeometry(polystr)

# %% [markdown]
# ### Now polygon is an appropriate object for using in with the Raster Object

# %% [markdown]
# ## Now let's load the Raster Models

# %%
from raster_api.tools import RasterData
from raster_api.models import raster_models

# %% [markdown]
# The 'raster_model' object is a list that contains all the currently available Raster Models.

# %%
raster_models
# Out:
# [raster_api.models.DemMex,
#  raster_api.models.Precipitation,
#  raster_api.models.SolarRadiation,
#  raster_api.models.MeanTemperature,
#  raster_api.models.MinTemperature,
#  raster_api.models.MaxTemperature,
#  raster_api.models.VaporPressure,
#  raster_api.models.WindSpeed]

# %% [markdown]
# Here well use as example precipitation data.

# %%
prec = RasterData(raster_models[1],polygon)

# %% [markdown]
# Once instantiated we need to retrieve the data to memory. (If we want to display it).

# %%
prec.getRaster()
# Out:
# DEBUG:django.db.backends:(2.174) SELECT ST_Clip(ST_Union("bioclim"."prec"."rast"),ST_GeomFromText('POLYGON ((-109 27, -106 27, -106 30, -109 30, -109 27))' , 4326)) AS "raster" FROM "bioclim"."prec" WHERE ST_Intersects( "bioclim"."prec"."rast" ,  ST_GeomFromText('POLYGON ((-109 27, -106 27, -106 30, -109 30, -109 27))' , 4326)  ); args=(<Polygon object at 0x7f21f2853130>,)

# %%
## Visualizing a layer stack

# %%
stats_dict = prec.rasterdata.allBandStatistics()

# %%
stats_dict
# Out:
# {'max': 287.0,
#  'mean': 51.682043467078074,
#  'mean_std': 18.347134216417988,
#  'min': 2.0,
#  'nodata': -32768}

# %%
import matplotlib.pyplot as plt

# %%
prec.display_field(stats_dict,band=1,cmap=plt.cm.rainbow,title='Precipitation')
# Out:
# <img src="data:image/png;base64,...">

# %%
prec.getSummaryStats()
# Out:
# DEBUG:django.db.backends:(1.493) SELECT ST_SummaryStats(ST_Clip(ST_Union("bioclim"."prec"."rast"),ST_GeomFromText('POLYGON ((-109 27, -106 27, -106 30, -109 30, -109 27))' , 4326))) AS "raster" FROM "bioclim"."prec" WHERE ST_Intersects( "bioclim"."prec"."rast" ,  ST_GeomFromText('POLYGON ((-109 27, -106 27, -106 30, -109 30, -109 27))' , 4326)  ); args=(<Polygon object at 0x7f21f2853130>,)
# {'count': 129600,
#  'max': 96.0,
#  'mean': 29.0873533950617,
#  'min': 6.0,
#  'stddev': 18.474224635038,
#  'sum': 3769721.0,
#  'uniqueid': 'SRID=4326;POLYGON ((-109 27, -106 27, -106 30, -109 30, -109 27))'}

# %%
for i in range(1,13):
    prec.display_field(stats_dict,band=i,cmap=plt.cm.rainbow,title='Precipitation')
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
