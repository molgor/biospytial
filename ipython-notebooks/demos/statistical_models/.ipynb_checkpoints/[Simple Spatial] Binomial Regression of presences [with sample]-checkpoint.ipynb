# %%
# %matplotlib inline
import sys
sys.path.append('/apps')
import django
django.setup()
from drivers.tree_builder import TreeNeo
from drivers.graph_models import TreeNode, Order, Family, graph,Kingdom,Occurrence
from drivers.graph_models import Cell,Mex4km, countObjectsOf
from drivers.graph_models import pickNode
import matplotlib.pyplot as plt
import pandas as pd
import itertools as it
import numpy as np

## Use the ggplot style
plt.style.use('ggplot')

# %% [markdown]
# # Spatial Regression for presences of certain taxon
# ---
# Abstraction dashboard for joininig the data with the model
#
# ***
# Here I show how to extract different taxonomic information at cell level.
# Although there exists a method for building the taxonomic tree within a single cell, the process can be computationally intensive because it depends on extracting the total amount of occurrences in each cell. From there, it traverses from top to bottom the tree looking for the corresponding nodes.
#
# The approach is usefull when one needs a small number of trees but it'll become increasingly slow if the amount of cells or occurrences increases.
#
# ---
#
# ## Extracting specific taxonomic levels en each cells
#
# The method studied here makes use of the relationship type `IS_IN` stored in the knowledge graph.
#
# > Developer's note: *There was a problem with the design of the OGM implementation (py2neo.ogm). The retrieval of linked nodes based on a specific relation does not distinguish different labels. In other words it returns the totality of the data that has the  specific relationship given a node.*
#
# > Patchy solution:
# The solution was to include extra methods for the class Cell `has_[taxas]`. This method/attribute returns a graph selector that points to the corresponding nodes.
#
# > Stable Fix:
# Make relationships as specific as possible (given the data). For example, if instead of using the relation type
# * *IS_IN* for (Bursera:Family) -[IS_IN]-> (Grid:Cell)
# change it to:
# * *Family_IS_IN* for (Bursera:Family) -[IS_IN]-> (Grid:Cell)
# Let's get started.
# As usual we need to load the necessary modules

# %%
## Let's pick the bats node
bats = pickNode(Order,name='Chiroptera')

# %%
ids4bats = bats.getCellsById()

# %% [markdown]
# ## Random selection of cells.
#
# > Note: Data Arquitecture. For storage reasons I couldn't load the complete world bioclimatic layers. Therefore I needed to put a regional subset that comprises only the Mexican Territory.
# For this reason, it is necessary that any approach for selecting subsamples needs to be constrained (filter) by this geometry.
# We can do that with this:

# %% [markdown]
# Obtain list of cells within the Mexican Territory.
# > The attribute: `mexican_cells.values` is a generator of the Type: QuerySet. We need to cast it to list for loading all the data in memory.

# %%
# Get all cell ids
#selected_cells = mexican_cells
selected_cells = ids4bats
#ids = list(selected_cells.values('pk'))

# %% [markdown]
# The UniformRandomCellSample is a method for sampling cells in the example below we give as arguments.

# %% [markdown]
# # Select uniformly random
# We will load the submodule `sampling` from the module `traversals`. This submodule has some sampling methods for selecting objects from the *Knowledge Graph*
#
# Usage:
#
# > ` sampling.UniformRandomCellSample(list_of_cell_ids, CellNodeClass, sample_size=100, with_replacement=False, random_seed='') `
#
# Returns:
# > <\py2neo.ogm.Mex4kmSelection\>

# %%
from traversals import sampling as sm
cells_with_bats = bats.is_in.related_class
N = 200
sample_cells = sm.UniformRandomCellSample(ids4bats,cells_with_bats,sample_size=N)
# Out:
# INFO Compiling Query and asking the Graph Database

# %% [markdown]
# ## Extract richness and Environmental covariates from cells at a given taxonomic level
#
# Inside the module  `traversals` there exists a submodule `strategies` which is composed of different traversal schemes for exploring the *Knowledge Graph*. Here we will use the function: `getEnvironmentalCovariatesFromListOfCells(sample_cells)` which will return a dataframe of the summary statistics for the environmental covariates given a list of Cell objects (`sample_cells`).

# %%
from traversals import strategies as st

# %%
# %time data = st.getEnvironmentalCovariatesFromListOfCells(sample_cells)
# Out:
# CPU times: user 10.7 s, sys: 204 ms, total: 10.9 s
# Wall time: 1min 39s

# %%
# %time coords = st.getCentroidsFromListofCells(sample_cells)
# Out:
# CPU times: user 6.28 s, sys: 88 ms, total: 6.36 s
# Wall time: 8.95 s

# %% [markdown]
# ### Build the trees from these cells
# Using the function for building cell to tree cells to trees

# %%
from drivers.tree_builder import buildTreeNeo

# %%
# %time cells = list(sample_cells)
# Out:
# CPU times: user 6.12 s, sys: 68 ms, total: 6.19 s
# Wall time: 8.93 s

# %%
# %time trees = map(lambda c : buildTreeNeo(c),cells)
# Out:
# CPU times: user 5min 44s, sys: 9.58 s, total: 5min 54s
# Wall time: 6min 55s

# %% [markdown]
# ## Calculating Node frequencies
# For achiving this we must first obtain the global tree within this region.
# It is only with a context in which we can obtain frequencies.
# In this case the context is the totallity of the trees. Given that each tree
# is a subtree of the tree of life and all share at least a common ancestor (Root)
# it is possible to make the union of this trees. As explained before [reference] the
# set of taxonomic trees allows a monadic structure (the addition). The union of two trees
# will then be called `addition` and will be denoted with the $\times$ symbol.
#
#
# > ### Implementation note:
# It is appealing to `integrate` a list of trees with a reduce function (fold).
# * `big_tree = reduce(lambda a,b : a + b ,trees)`
# /n Doing so will require a much higher processing time.
#
# The most efficient way of calculating the union (merge) of a list of trees is by first extracting the occurrences and, by making use of the Taxonomic relationships obtaining the resulting tree.

# %%
# %time ocs = reduce(lambda a,b : a + b ,map(lambda t : t.occurrences, trees))
# Out:
# CPU times: user 168 ms, sys: 4 ms, total: 172 ms
# Wall time: 173 ms

# %%
## Ohh! super fast (compared to the other method that takes more than 20 minutes for this sample size)
# %time bigtree = TreeNeo(ocs,cell_objects=cells)
# Out:
# CPU times: user 3.41 s, sys: 12 ms, total: 3.42 s
# Wall time: 3.42 s

# %% [markdown]
# ### Now let´s calculate the spatial frequencies

# %%
bigtree.countNodesFrequenciesOnList(trees)
# Out:
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.115
# INFO Going deep 0.05
# INFO Going deep 0.025
# INFO Going deep 0.16
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.06
# INFO Going deep 0.03
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.16
# INFO Going deep 0.045
# INFO Going deep 0.045
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.035
# INFO Going deep 0.115
# INFO Going deep 0.115
# INFO Going deep 0.315
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.025
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.055
# INFO Going deep 0.065
# INFO Going deep 0.335
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.05
# INFO Going deep 0.05
# INFO Going deep 0.05
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.06
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.075
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.085
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.055
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.09
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.13
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.045
# INFO Going deep 0.135
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.035
# INFO Going deep 0.15
# INFO Going deep 0.135
# INFO Going deep 0.035
# INFO Going deep 0.22
# INFO Going deep 0.06
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.075
# INFO Going deep 0.025
# INFO Going deep 0.275
# INFO Going deep 0.04
# INFO Going deep 0.04
# INFO Going deep 0.015
# INFO Going deep 0.06
# INFO Going deep 0.28
# INFO Going deep 0.05
# INFO Going deep 0.05
# INFO Going deep 0.05
# INFO Going deep 0.03
# INFO Going deep 0.03
# INFO Going deep 0.045
# INFO Going deep 0.045
# INFO Going deep 0.03
# INFO Going deep 0.165
# INFO Going deep 0.025
# INFO Going deep 0.19
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.05
# INFO Going deep 0.045
# INFO Going deep 0.065
# INFO Going deep 0.005
# INFO Going deep 0.155
# INFO Going deep 0.025
# INFO Going deep 0.24
# INFO Going deep 0.095
# INFO Going deep 0.08
# INFO Going deep 0.12
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.105
# INFO Going deep 0.12
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.095
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.03
# INFO Going deep 0.115
# INFO Going deep 0.055
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.01
# INFO Going deep 0.115
# INFO Going deep 0.145
# INFO Going deep 0.08
# INFO Going deep 0.01
# INFO Going deep 0.21
# INFO Going deep 0.035
# INFO Going deep 0.035
# INFO Going deep 0.065
# INFO Going deep 0.015
# INFO Going deep 0.025
# INFO Going deep 0.125
# INFO Going deep 0.045
# INFO Going deep 0.105
# INFO Going deep 0.005
# INFO Going deep 0.13
# INFO Going deep 0.015
# INFO Going deep 0.03
# INFO Going deep 0.105
# INFO Going deep 0.065
# INFO Going deep 0.025
# INFO Going deep 0.075
# INFO Going deep 0.175
# INFO Going deep 0.065
# INFO Going deep 0.05
# INFO Going deep 0.06
# INFO Going deep 0.115
# INFO Going deep 0.065
# INFO Going deep 0.29
# INFO Going deep 0.09
# INFO Going deep 0.09
# INFO Going deep 0.04
# INFO Going deep 0.04
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.055
# INFO Going deep 0.06
# INFO Going deep 0.055
# INFO Going deep 0.055
# INFO Going deep 0.03
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.06
# INFO Going deep 0.07
# INFO Going deep 0.175
# INFO Going deep 0.105
# INFO Going deep 0.055
# INFO Going deep 0.035
# INFO Going deep 0.045
# INFO Going deep 0.22
# INFO Going deep 0.01
# INFO Going deep 0.16
# INFO Going deep 0.19
# INFO Going deep 0.02
# INFO Going deep 0.03
# INFO Going deep 0.135
# INFO Going deep 0.05
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.19
# INFO Going deep 0.005
# INFO Going deep 0.075
# INFO Going deep 0.015
# INFO Going deep 0.045
# INFO Going deep 0.065
# INFO Going deep 0.065
# INFO Going deep 0.19
# INFO Going deep 0.095
# INFO Going deep 0.04
# INFO Going deep 0.1
# INFO Going deep 0.01
# INFO Going deep 0.115
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.335
# INFO Going deep 0.035
# INFO Going deep 0.165
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.04
# INFO Going deep 0.205
# INFO Going deep 0.125
# INFO Going deep 0.035
# INFO Going deep 0.07
# INFO Going deep 0.045
# INFO Going deep 0.27
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.165
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.07
# INFO Going deep 0.065
# INFO Going deep 0.015
# INFO Going deep 0.125
# INFO Going deep 0.12
# INFO Going deep 0.235
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.035
# INFO Going deep 0.035
# INFO Going deep 0.135
# INFO Going deep 0.025
# INFO Going deep 0.065
# INFO Going deep 0.07
# INFO Going deep 0.06
# INFO Going deep 0.205
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.04
# INFO Going deep 0.04
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.115
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.14
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.055
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.04
# INFO Going deep 0.075
# INFO Going deep 0.21
# INFO Going deep 0.06
# INFO Going deep 0.075
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.025
# INFO Going deep 0.04
# INFO Going deep 0.115
# INFO Going deep 0.13
# INFO Going deep 0.01
# INFO Going deep 0.045
# INFO Going deep 0.015
# INFO Going deep 0.05
# INFO Going deep 0.085
# INFO Going deep 0.275
# INFO Going deep 0.05
# INFO Going deep 0.205
# INFO Going deep 0.045
# INFO Going deep 0.01
# INFO Going deep 0.22
# INFO Going deep 0.07
# INFO Going deep 0.01
# INFO Going deep 0.045
# INFO Going deep 0.09
# INFO Going deep 0.13
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.1
# INFO Going deep 0.01
# INFO Going deep 0.035
# INFO Going deep 0.015
# INFO Going deep 0.085
# INFO Going deep 0.04
# INFO Going deep 0.075
# INFO Going deep 0.075
# INFO Going deep 0.005
# INFO Going deep 0.055
# INFO Going deep 0.035
# INFO Going deep 0.05
# INFO Going deep 0.315
# INFO Going deep 0.47
# INFO Going deep 0.05
# INFO Going deep 0.05
# INFO Going deep 0.05
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.055
# INFO Going deep 0.005
# INFO Going deep 0.085
# INFO Going deep 0.085
# INFO Going deep 0.02
# INFO Going deep 0.025
# INFO Going deep 0.075
# INFO Going deep 0.01
# INFO Going deep 0.09
# INFO Going deep 0.09
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.1
# INFO Going deep 0.005
# INFO Going deep 0.065
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.125
# INFO Going deep 0.125
# INFO Going deep 0.09
# INFO Going deep 0.145
# INFO Going deep 0.08
# INFO Going deep 0.015
# INFO Going deep 0.21
# INFO Going deep 0.02
# INFO Going deep 0.11
# INFO Going deep 0.01
# INFO Going deep 0.265
# INFO Going deep 0.265
# INFO Going deep 0.08
# INFO Going deep 0.075
# INFO Going deep 0.1
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.105
# INFO Going deep 0.115
# INFO Going deep 0.17
# INFO Going deep 0.04
# INFO Going deep 0.025
# INFO Going deep 0.065
# INFO Going deep 0.005
# INFO Going deep 0.105
# INFO Going deep 0.055
# INFO Going deep 0.035
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.065
# INFO Going deep 0.18
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.025
# INFO Going deep 0.05
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.075
# INFO Going deep 0.035
# INFO Going deep 0.03
# INFO Going deep 0.03
# INFO Going deep 0.06
# INFO Going deep 0.28
# INFO Going deep 0.285
# INFO Going deep 0.105
# INFO Going deep 0.005
# INFO Going deep 0.11
# INFO Going deep 0.11
# INFO Going deep 0.025
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.04
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.09
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.145
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.01
# INFO Going deep 0.04
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.18
# INFO Going deep 0.215
# INFO Going deep 0.135
# INFO Going deep 0.035
# INFO Going deep 0.13
# INFO Going deep 0.05
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.2
# INFO Going deep 0.2
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.075
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.055
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.12
# INFO Going deep 0.13
# INFO Going deep 0.085
# INFO Going deep 0.105
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.05
# INFO Going deep 0.015
# INFO Going deep 0.12
# INFO Going deep 0.14
# INFO Going deep 0.03
# INFO Going deep 0.185
# INFO Going deep 0.045
# INFO Going deep 0.06
# INFO Going deep 0.015
# INFO Going deep 0.07
# INFO Going deep 0.09
# INFO Going deep 0.09
# INFO Going deep 0.195
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.17
# INFO Going deep 0.01
# INFO Going deep 0.06
# INFO Going deep 0.04
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.115
# INFO Going deep 0.245
# INFO Going deep 0.005
# INFO Going deep 0.2
# INFO Going deep 0.16
# INFO Going deep 0.22
# INFO Going deep 0.065
# INFO Going deep 0.065
# INFO Going deep 0.275
# INFO Going deep 0.055
# INFO Going deep 0.13
# INFO Going deep 0.035
# INFO Going deep 0.04
# INFO Going deep 0.16
# INFO Going deep 0.16
# INFO Going deep 0.005
# INFO Going deep 0.065
# INFO Going deep 0.02
# INFO Going deep 0.055
# INFO Going deep 0.095
# INFO Going deep 0.095
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.055
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.09
# INFO Going deep 0.045
# INFO Going deep 0.125
# INFO Going deep 0.06
# INFO Going deep 0.06
# INFO Going deep 0.04
# INFO Going deep 0.025
# INFO Going deep 0.035
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.07
# INFO Going deep 0.08
# INFO Going deep 0.005
# INFO Going deep 0.08
# INFO Going deep 0.06
# INFO Going deep 0.03
# INFO Going deep 0.065
# INFO Going deep 0.165
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.04
# INFO Going deep 0.04
# INFO Going deep 0.125
# INFO Going deep 0.125
# INFO Going deep 0.035
# INFO Going deep 0.035
# INFO Going deep 0.125
# INFO Going deep 0.525
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.235
# INFO Going deep 0.025
# INFO Going deep 0.03
# INFO Going deep 0.03
# INFO Going deep 0.06
# INFO Going deep 0.265
# INFO Going deep 0.1
# INFO Going deep 0.1
# INFO Going deep 0.15
# INFO Going deep 0.02
# INFO Going deep 0.035
# INFO Going deep 0.175
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.055
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.08
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.035
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.05
# INFO Going deep 0.04
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.04
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.025
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.065
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.29
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.06
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.055
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.03
# INFO Going deep 0.03
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.455
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.045
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.07
# INFO Going deep 0.465
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.025
# INFO Going deep 0.035
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.055
# INFO Going deep 0.04
# INFO Going deep 0.035
# INFO Going deep 0.02
# INFO Going deep 0.03
# INFO Going deep 0.1
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.035
# INFO Going deep 0.04
# INFO Going deep 0.015
# INFO Going deep 0.045
# INFO Going deep 0.025
# INFO Going deep 0.03
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.06
# INFO Going deep 0.17
# INFO Going deep 0.04
# INFO Going deep 0.04
# INFO Going deep 0.02
# INFO Going deep 0.09
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.03
# INFO Going deep 0.16
# INFO Going deep 0.055
# INFO Going deep 0.055
# INFO Going deep 0.035
# INFO Going deep 0.035
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.055
# INFO Going deep 0.135
# INFO Going deep 0.015
# INFO Going deep 0.285
# INFO Going deep 0.01
# INFO Going deep 0.055
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.335
# INFO Going deep 0.02
# INFO Going deep 0.05
# INFO Going deep 0.07
# INFO Going deep 0.245
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.13
# INFO Going deep 0.23
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.075
# INFO Going deep 0.74
# INFO Going deep 0.05
# INFO Going deep 0.04
# INFO Going deep 0.01
# INFO Going deep 0.035
# INFO Going deep 0.13
# INFO Going deep 0.19
# INFO Going deep 0.085
# INFO Going deep 0.04
# INFO Going deep 0.375
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.075
# INFO Going deep 0.015
# INFO Going deep 0.11
# INFO Going deep 0.09
# INFO Going deep 0.155
# INFO Going deep 0.195
# INFO Going deep 1.0
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.1
# INFO Going deep 0.02
# INFO Going deep 0.04
# INFO Going deep 0.16
# INFO Going deep 0.16
# INFO Going deep 0.015
# INFO Going deep 0.08
# INFO Going deep 0.085
# INFO Going deep 0.085
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.03
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.085
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.105
# INFO Going deep 0.105
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.035
# INFO Going deep 0.2
# INFO Going deep 0.05
# INFO Going deep 0.025
# INFO Going deep 0.065
# INFO Going deep 0.085
# INFO Going deep 0.325
# INFO Going deep 0.02
# INFO Going deep 0.205
# INFO Going deep 0.4
# INFO Going deep 0.145
# INFO Going deep 0.135
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.11
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.05
# INFO Going deep 0.015
# INFO Going deep 0.115
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.56
# INFO Going deep 0.035
# INFO Going deep 0.015
# INFO Going deep 0.025
# INFO Going deep 0.045
# INFO Going deep 0.115
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.1
# INFO Going deep 0.015
# INFO Going deep 0.155
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.635
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 1.0
# INFO Going deep 1.0
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.03
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.025
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.035
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.06
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.035
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.025
# INFO Going deep 0.075
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.115
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.06
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.06
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.045
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.115
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.07
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.05
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.2
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.305
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.045
# INFO Going deep 0.32
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 1.0
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.035
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.05
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.035
# INFO Going deep 0.045
# INFO Going deep 0.045
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.06
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.075
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.045
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.105
# INFO Going deep 0.11
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.055
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.04
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.035
# INFO Going deep 0.035
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.05
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.15
# INFO Going deep 0.15
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.095
# INFO Going deep 0.115
# INFO Going deep 0.015
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.045
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.025
# INFO Going deep 0.045
# INFO Going deep 0.02
# INFO Going deep 0.09
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.03
# INFO Going deep 0.025
# INFO Going deep 0.14
# INFO Going deep 0.155
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.035
# INFO Going deep 0.05
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.04
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.025
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.11
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.05
# INFO Going deep 0.13
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.035
# INFO Going deep 0.23
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.07
# INFO Going deep 0.07
# INFO Going deep 0.075
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.03
# INFO Going deep 0.035
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.05
# INFO Going deep 0.08
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.075
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.05
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.035
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.06
# INFO Going deep 0.005
# INFO Going deep 0.115
# INFO Going deep 0.035
# INFO Going deep 0.045
# INFO Going deep 0.03
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.06
# INFO Going deep 0.05
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.11
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.08
# INFO Going deep 0.01
# INFO Going deep 0.04
# INFO Going deep 0.02
# INFO Going deep 0.09
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.04
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.08
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.105
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.435
# INFO Going deep 0.005
# INFO Going deep 0.1
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.14
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.03
# INFO Going deep 0.04
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.045
# INFO Going deep 0.125
# INFO Going deep 0.07
# INFO Going deep 0.025
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.025
# ...
# INFO Going deep 0.05
# INFO Going deep 0.005
# INFO Going deep 0.135
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.065
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.07
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.095
# INFO Going deep 0.015
# INFO Going deep 0.06
# INFO Going deep 0.135
# INFO Going deep 0.25
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.055
# INFO Going deep 0.065
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.08
# INFO Going deep 0.005
# INFO Going deep 0.055
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.08
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.09
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.035
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.13
# INFO Going deep 0.135
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.14
# INFO Going deep 0.275
# INFO Going deep 0.005
# INFO Going deep 0.04
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.09
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.02
# INFO Going deep 0.035
# INFO Going deep 0.035
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.03
# INFO Going deep 0.035
# INFO Going deep 0.04
# INFO Going deep 0.02
# INFO Going deep 0.04
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.065
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.04
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.215
# INFO Going deep 0.23
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.04
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.06
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.06
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.105
# INFO Going deep 0.03
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.14
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.015
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.015
# INFO Going deep 0.135
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.215
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.265
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.065
# INFO Going deep 0.035
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.1
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.035
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.04
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.075
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.05
# INFO Going deep 0.05
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.03
# INFO Going deep 0.015
# INFO Going deep 0.055
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.21
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.08
# INFO Going deep 0.08
# INFO Going deep 0.11
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.025
# INFO Going deep 0.035
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.045
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.025
# INFO Going deep 0.04
# INFO Going deep 0.065
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.095
# INFO Going deep 0.025
# INFO Going deep 0.04
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.145
# INFO Going deep 0.09
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.045
# INFO Going deep 0.065
# INFO Going deep 0.005
# INFO Going deep 0.075
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.025
# INFO Going deep 0.02
# INFO Going deep 0.1
# INFO Going deep 0.135
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.155
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.08
# INFO Going deep 0.035
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.475
# INFO Going deep 0.48
# INFO Going deep 0.11
# INFO Going deep 0.015
# INFO Going deep 0.11
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.09
# INFO Going deep 0.13
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.155
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.025
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.265
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.04
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.04
# INFO Going deep 0.06
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.105
# INFO Going deep 0.025
# INFO Going deep 0.05
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.055
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.135
# INFO Going deep 0.05
# INFO Going deep 0.05
# INFO Going deep 0.005
# INFO Going deep 0.05
# INFO Going deep 0.005
# INFO Going deep 0.055
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.35
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.045
# INFO Going deep 0.035
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.065
# INFO Going deep 0.065
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.06
# INFO Going deep 0.015
# INFO Going deep 0.07
# INFO Going deep 0.07
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.115
# INFO Going deep 0.045
# INFO Going deep 0.045
# INFO Going deep 0.125
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.035
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.065
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.05
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.05
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.04
# INFO Going deep 0.18
# INFO Going deep 0.065
# INFO Going deep 0.03
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.025
# INFO Going deep 0.015
# INFO Going deep 0.04
# INFO Going deep 0.165
# INFO Going deep 0.165
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.72
# INFO Going deep 0.77
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.055
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.01
# INFO Going deep 0.115
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.035
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.06
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.04
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.04
# INFO Going deep 0.005
# INFO Going deep 0.04
# INFO Going deep 0.02
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.025
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.16
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.03
# INFO Going deep 0.03
# INFO Going deep 0.045
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.02
# INFO Going deep 0.19
# INFO Going deep 0.19
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.02
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.03
# INFO Going deep 0.015
# INFO Going deep 0.005
# INFO Going deep 0.04
# INFO Going deep 0.01
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.025
# INFO Going deep 0.03
# INFO Going deep 0.07
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.095
# INFO Going deep 0.095
# INFO Going deep 0.095
# INFO Going deep 0.005
# INFO Going deep 0.01
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.015
# INFO Going deep 0.785
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# INFO Going deep 0.005
# 0.05

# %%
soyunagraphica = bigtree.toNetworkx(depth_level=6)
nombres = bigtree.toNetworkx(depth_level=5)

# %%
import networkx as nt
from networkx.drawing.nx_agraph import graphviz_layout
extractNames = lambda graph : {k:v for (k,v) in map(lambda n : (n,n.name),
                                                    graph.nodes())}
extractColors = lambda graph :  map(lambda n : 
                                    n.level,graph.nodes())
extractfreqs = lambda graph : np.array(map(lambda (k,v) : 
                        v['freq'],graph.nodes(data=True)))
root = bigtree.node
pos = graphviz_layout(soyunagraphica,prog='circo',root=root.node.name)
nt.draw(soyunagraphica,pos,labels=extractNames(soyunagraphica),
        node_color=extractColors(soyunagraphica), 
        node_size=extractfreqs(soyunagraphica)*100
       )
#nt.draw(soyunagraphica,pos)
plt.show()

# %%
soyunagraphica.size()
# Out:
# 3448

# %% [markdown]
# we will use `between_centrality` for obtaining a relevant metric of node importance. We will add this new value to the graph as a new attribute: `centrality`

# %%
# %time gigi = nt.algorithms.betweenness_centrality(soyunagraphica)
# Out:
# CPU times: user 19min 9s, sys: 108 ms, total: 19min 10s
# Wall time: 19min 11s

# %% [markdown]
# Here we'll add the between centrality as a new attribute:

# %%
nt.set_node_attributes(soyunagraphica, 'betweenness', gigi)
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# <ipython-input-2-e5b04a849353> in <module>()
# ----> 1 nt.set_node_attributes(soyunagraphica, 'betweenness', gigi)
#
# NameError: name 'nt' is not defined

# %%
extractbetweeness = lambda graph :  np.array(map(lambda (k,v) : v['betweenness'],
                                                 graph.nodes(data=True)
                                                ))

# %%
bc = 1 + (extractbetweeness(soyunagraphica) * 7000)
freqs = extractfreqs(soyunagraphica) * 2000

# %%
import matplotlib as mtp
plt.figure(figsize=(20,20))
plt.title("Union of trees for a random cell sample (color between centrality, size: freq in cells)")
plt.xlabel("Between Centrality")
root = bigtree.node
pos = graphviz_layout(soyunagraphica,prog='twopi',root=root.node.name)
nt.draw(soyunagraphica,pos,
       labels=extractNames(nombres),
        #node_color=extractColors(soyunagraphica), 
        node_color=bc, 
        node_size=freqs,
        cmap=plt.cm.hot,
        title="Union of trees for a random cell sample"
       )
#nt.draw(soyunagraphica,pos)
#plt.show()
norm = mtp.colors.Normalize(vmin=min(bc),vmax=max(bc))
sm = plt.cm.ScalarMappable(cmap=plt.cm.hot, norm=norm)
sm.set_array([])
plt.colorbar(sm,orientation="horizontal",pad=-0.01)

plt.savefig("/outputs/graph_centrality.png", format="PNG")

# %% [markdown]
# > ### Figure 1:
# The global tree reulting by fusing the selected random cells. The color of the node represents the taxonomic level. The size is proportional to the between centrality.

# %%
cosas = soyunagraphica.nodes(data=True)

# %%
cosas.sort(key=lambda (k,v) : v,reverse=True)

# %%
orders = filter(lambda (k,v) : k.level==4,cosas)

# %%
orders
# Out:
# [(<TreeNode type: Order id = 729 name: Passeriformes>,
#   {'betweenness': 0.12224204510193133,
#    'freq': 0.47,
#    'level': 4,
#    'richness': 10012}),
#  (<TreeNode type: Order id = 797 name: Lepidoptera>,
#   {'betweenness': 0.1033362680618743,
#    'freq': 0.115,
#    'level': 4,
#    'richness': 3469}),
#  (<TreeNode type: Order id = 1457 name: Hymenoptera>,
#   {'betweenness': 0.07470667859404963,
#    'freq': 0.115,
#    'level': 4,
#    'richness': 1835}),
#  (<TreeNode type: Order id = 1369 name: Poales>,
#   {'betweenness': 0.0704556973783316,
#    'freq': 0.5,
#    'level': 4,
#    'richness': 1025}),
#  (<TreeNode type: Order id = 408 name: Lamiales>,
#   {'betweenness': 0.06547406299031337,
#    'freq': 0.385,
#    'level': 4,
#    'richness': 526}),
#  (<TreeNode type: Order id = 715 name: Squamata>,
#   {'betweenness': 0.06427089159880106,
#    'freq': 0.455,
#    'level': 4,
#    'richness': 2265}),
#  (<TreeNode type: Order id = 414 name: Asterales>,
#   {'betweenness': 0.06187683294327021,
#    'freq': 0.44,
#    'level': 4,
#    'richness': 665}),
#  (<TreeNode type: Order id = 1470 name: Coleoptera>,
#   {'betweenness': 0.061006510924123125,
#    'freq': 0.2,
#    'level': 4,
#    'richness': 845}),
#  (<TreeNode type: Order id = 1370 name: Fabales>,
#   {'betweenness': 0.052014697874408426,
#    'freq': 0.48,
#    'level': 4,
#    'richness': 1071}),
#  (<TreeNode type: Order id = 1169 name: Asparagales>,
#   {'betweenness': 0.05119283926236002,
#    'freq': 0.23,
#    'level': 4,
#    'richness': 262}),
#  (<TreeNode type: Order id = 422 name: Caryophyllales>,
#   {'betweenness': 0.046954478725573935,
#    'freq': 0.285,
#    'level': 4,
#    'richness': 276}),
#  (<TreeNode type: Order id = 1414 name: Malpighiales>,
#   {'betweenness': 0.04637594680333347,
#    'freq': 0.35,
#    'level': 4,
#    'richness': 504}),
#  (<TreeNode type: Order id = 412 name: Gentianales>,
#   {'betweenness': 0.04231595852878558,
#    'freq': 0.36,
#    'level': 4,
#    'richness': 545}),
#  (<TreeNode type: Order id = 392 name: Polypodiales>,
#   {'betweenness': 0.031044346036803918,
#    'freq': 0.16,
#    'level': 4,
#    'richness': 219}),
#  (<TreeNode type: Order id = 734 name: Chiroptera>,
#   {'betweenness': 0.031011532271580853,
#    'freq': 1.0,
#    'level': 4,
#    'richness': 4260}),
#  (<TreeNode type: Order id = 587 name: Perciformes>,
#   {'betweenness': 0.02992110561186061,
#    'freq': 0.09,
#    'level': 4,
#    'richness': 125}),
#  (<TreeNode type: Order id = 941 name: Malvales>,
#   {'betweenness': 0.028657186685755863,
#    'freq': 0.23,
#    'level': 4,
#    'richness': 237}),
#  (<TreeNode type: Order id = 933 name: Sapindales>,
#   {'betweenness': 0.027039383922399313,
#    'freq': 0.275,
#    'level': 4,
#    'richness': 269}),
#  (<TreeNode type: Order id = 1459 name: Rodentia>,
#   {'betweenness': 0.024753694829964114,
#    'freq': 0.635,
#    'level': 4,
#    'richness': 4482}),
#  (<TreeNode type: Order id = 691 name: Rosales>,
#   {'betweenness': 0.023617497174650674,
#    'freq': 0.25,
#    'level': 4,
#    'richness': 240}),
#  (<TreeNode type: Order id = 617 name: Hypnales>,
#   {'betweenness': 0.023058316960105865,
#    'freq': 0.075,
#    'level': 4,
#    'richness': 123}),
#  (<TreeNode type: Order id = 690 name: Myrtales>,
#   {'betweenness': 0.02247574642060718,
#    'freq': 0.26,
#    'level': 4,
#    'richness': 195}),
#  (<TreeNode type: Order id = 952 name: Anura>,
#   {'betweenness': 0.022471202976191675,
#    'freq': 0.315,
#    'level': 4,
#    'richness': 1041}),
#  (<TreeNode type: Order id = 1353 name: Ericales>,
#   {'betweenness': 0.02134173634964194,
#    'freq': 0.21,
#    'level': 4,
#    'richness': 154}),
#  (<TreeNode type: Order id = 546 name: Collembola>,
#   {'betweenness': 0.01904241692396024,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 50}),
#  (<TreeNode type: Order id = 789 name: Odonata>,
#   {'betweenness': 0.019035517619477443,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 216}),
#  (<TreeNode type: Order id = 7225535 name: Brassicales>,
#   {'betweenness': 0.0178856896309175,
#    'freq': 0.18,
#    'level': 4,
#    'richness': 81}),
#  (<TreeNode type: Order id = 1176 name: Solanales>,
#   {'betweenness': 0.016731823025099332,
#    'freq': 0.265,
#    'level': 4,
#    'richness': 243}),
#  (<TreeNode type: Order id = 1448 name: Apodiformes>,
#   {'betweenness': 0.01556163367452918,
#    'freq': 0.285,
#    'level': 4,
#    'richness': 742}),
#  (<TreeNode type: Order id = 621 name: Pottiales>,
#   {'betweenness': 0.01383882686245883,
#    'freq': 0.11,
#    'level': 4,
#    'richness': 135}),
#  (<TreeNode type: Order id = 1340 name: Leucodontales>,
#   {'betweenness': 0.013291089396812318,
#    'freq': 0.05,
#    'level': 4,
#    'richness': 86}),
#  (<TreeNode type: Order id = 7192402 name: Charadriiformes>,
#   {'betweenness': 0.013288733536745022,
#    'freq': 0.165,
#    'level': 4,
#    'richness': 448}),
#  (<TreeNode type: Order id = 7191147 name: Accipitriformes>,
#   {'betweenness': 0.013274430100622148,
#    'freq': 0.275,
#    'level': 4,
#    'richness': 754}),
#  (<TreeNode type: Order id = 809 name: Hemiptera>,
#   {'betweenness': 0.0127160912646728,
#    'freq': 0.06,
#    'level': 4,
#    'richness': 36}),
#  (<TreeNode type: Order id = 732 name: Carnivora>,
#   {'betweenness': 0.012715586437515523,
#    'freq': 0.17,
#    'level': 4,
#    'richness': 171}),
#  (<TreeNode type: Order id = 7224005 name: Cucurbitales>,
#   {'betweenness': 0.012690008528213443,
#    'freq': 0.125,
#    'level': 4,
#    'richness': 79}),
#  (<TreeNode type: Order id = 1450 name: Strigiformes>,
#   {'betweenness': 0.012134193828050486,
#    'freq': 0.215,
#    'level': 4,
#    'richness': 309}),
#  (<TreeNode type: Order id = 7226464 name: Boraginales>,
#   {'betweenness': 0.01153698330099074,
#    'freq': 0.165,
#    'level': 4,
#    'richness': 116}),
#  (<TreeNode type: Order id = 547 name: Cyprinodontiformes>,
#   {'betweenness': 0.010984702390928726,
#    'freq': 0.085,
#    'level': 4,
#    'richness': 80}),
#  (<TreeNode type: Order id = 551 name: Alismatales>,
#   {'betweenness': 0.01098167342798506,
#    'freq': 0.115,
#    'level': 4,
#    'richness': 69}),
#  (<TreeNode type: Order id = 7219248 name: Saxifragales>,
#   {'betweenness': 0.009834201299492413,
#    'freq': 0.045,
#    'level': 4,
#    'richness': 21}),
#  (<TreeNode type: Order id = 7190953 name: Pelecaniformes>,
#   {'betweenness': 0.009827470270728708,
#    'freq': 0.195,
#    'level': 4,
#    'richness': 607}),
#  (<TreeNode type: Order id = 1048 name: Lecanorales>,
#   {'betweenness': 0.009258530064476524,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 9}),
#  (<TreeNode type: Order id = 399 name: Ranunculales>,
#   {'betweenness': 0.00925701558300469,
#    'freq': 0.135,
#    'level': 4,
#    'richness': 43}),
#  (<TreeNode type: Order id = 1366 name: Siphonaptera>,
#   {'betweenness': 0.009256679031566505,
#    'freq': 0.025,
#    'level': 4,
#    'richness': 174}),
#  (<TreeNode type: Order id = 1354 name: Fagales>,
#   {'betweenness': 0.00810230759859106,
#    'freq': 0.11,
#    'level': 4,
#    'richness': 62}),
#  (<TreeNode type: Order id = 407 name: Laurales>,
#   {'betweenness': 0.008100120014242856,
#    'freq': 0.105,
#    'level': 4,
#    'richness': 47}),
#  (<TreeNode type: Order id = 1351 name: Apiales>,
#   {'betweenness': 0.008097595878456466,
#    'freq': 0.1,
#    'level': 4,
#    'richness': 50}),
#  (<TreeNode type: Order id = 724 name: Piciformes>,
#   {'betweenness': 0.008096754499861004,
#    'freq': 0.28,
#    'level': 4,
#    'richness': 616}),
#  (<TreeNode type: Order id = 1493 name: Gruiformes>,
#   {'betweenness': 0.007521083264845115,
#    'freq': 0.13,
#    'level': 4,
#    'richness': 144}),
#  (<TreeNode type: Order id = 640 name: Pinales>,
#   {'betweenness': 0.006947094787020153,
#    'freq': 0.095,
#    'level': 4,
#    'richness': 55}),
#  (<TreeNode type: Order id = 1333 name: Bryales>,
#   {'betweenness': 0.0069469265113010605,
#    'freq': 0.06,
#    'level': 4,
#    'richness': 39}),
#  (<TreeNode type: Order id = 553 name: Commelinales>,
#   {'betweenness': 0.0069437292726383,
#    'freq': 0.155,
#    'level': 4,
#    'richness': 71}),
#  (<TreeNode type: Order id = 1108 name: Anseriformes>,
#   {'betweenness': 0.006938344449627336,
#    'freq': 0.085,
#    'level': 4,
#    'richness': 196}),
#  (<TreeNode type: Order id = 793 name: Testudines>,
#   {'betweenness': 0.006370077346251523,
#    'freq': 0.07,
#    'level': 4,
#    'richness': 18}),
#  (<TreeNode type: Order id = 627 name: Zingiberales>,
#   {'betweenness': 0.006370077346251523,
#    'freq': 0.05,
#    'level': 4,
#    'richness': 28}),
#  (<TreeNode type: Order id = 637 name: Decapoda>,
#   {'betweenness': 0.006370077346251523,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 10}),
#  (<TreeNode type: Order id = 1002 name: Psocoptera>,
#   {'betweenness': 0.006370077346251523,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 12}),
#  (<TreeNode type: Order id = 934 name: Santalales>,
#   {'betweenness': 0.006369404243375153,
#    'freq': 0.09,
#    'level': 4,
#    'richness': 34}),
#  (<TreeNode type: Order id = 545 name: Diplostraca>,
#   {'betweenness': 0.0063680580376224115,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 17}),
#  (<TreeNode type: Order id = 377 name: Porellales>,
#   {'betweenness': 0.006367384934746041,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 33}),
#  (<TreeNode type: Order id = 723 name: Galliformes>,
#   {'betweenness': 0.0063660387289933,
#    'freq': 0.15,
#    'level': 4,
#    'richness': 138}),
#  (<TreeNode type: Order id = 1335 name: Dicranales>,
#   {'betweenness': 0.0057880116339101145,
#    'freq': 0.045,
#    'level': 4,
#    'richness': 56}),
#  (<TreeNode type: Order id = 1341 name: Orthotrichales>,
#   {'betweenness': 0.005212340398894226,
#    'freq': 0.035,
#    'level': 4,
#    'richness': 17}),
#  (<TreeNode type: Order id = 1153 name: Cypriniformes>,
#   {'betweenness': 0.0052106576417033,
#    'freq': 0.035,
#    'level': 4,
#    'richness': 15}),
#  (<TreeNode type: Order id = 1446 name: Columbiformes>,
#   {'betweenness': 0.005208301781636004,
#    'freq': 0.265,
#    'level': 4,
#    'richness': 703}),
#  (<TreeNode type: Order id = 950 name: Celastrales>,
#   {'betweenness': 0.005208301781636004,
#    'freq': 0.06,
#    'level': 4,
#    'richness': 27}),
#  (<TreeNode type: Order id = 687 name: Cyclopoida>,
#   {'betweenness': 0.005208301781636004,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 19}),
#  (<TreeNode type: Order id = 7192775 name: Suliformes>,
#   {'betweenness': 0.004634986406687412,
#    'freq': 0.125,
#    'level': 4,
#    'richness': 154}),
#  (<TreeNode type: Order id = 1172 name: Liliales>,
#   {'betweenness': 0.004634986406687412,
#    'freq': 0.035,
#    'level': 4,
#    'richness': 14}),
#  (<TreeNode type: Order id = 731 name: Artiodactyla>,
#   {'betweenness': 0.004634481579530133,
#    'freq': 0.035,
#    'level': 4,
#    'richness': 102}),
#  (<TreeNode type: Order id = 949 name: Cornales>,
#   {'betweenness': 0.004634313303811041,
#    'freq': 0.06,
#    'level': 4,
#    'richness': 23}),
#  (<TreeNode type: Order id = 708 name: Siluriformes>,
#   {'betweenness': 0.004634313303811041,
#    'freq': 0.03,
#    'level': 4,
#    'richness': 9}),
#  (<TreeNode type: Order id = 1339 name: Hookeriales>,
#   {'betweenness': 0.0046336402009346704,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 14}),
#  (<TreeNode type: Order id = 953 name: Caudata>,
#   {'betweenness': 0.0046329670980583,
#    'freq': 0.065,
#    'level': 4,
#    'richness': 722}),
#  (<TreeNode type: Order id = 1445 name: Psittaciformes>,
#   {'betweenness': 0.0046309477894291885,
#    'freq': 0.125,
#    'level': 4,
#    'richness': 225}),
#  (<TreeNode type: Order id = 7224021 name: Oxalidales>,
#   {'betweenness': 0.00405594965728967,
#    'freq': 0.045,
#    'level': 4,
#    'richness': 12}),
#  (<TreeNode type: Order id = 946 name: Dipsacales>,
#   {'betweenness': 0.00405594965728967,
#    'freq': 0.03,
#    'level': 4,
#    'richness': 9}),
#  (<TreeNode type: Order id = 1501 name: Neuroptera>,
#   {'betweenness': 0.00405594965728967,
#    'freq': 0.02,
#    'level': 4,
#    'richness': 11}),
#  (<TreeNode type: Order id = 1456 name: Stylommatophora>,
#   {'betweenness': 0.00405594965728967,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 6}),
#  (<TreeNode type: Order id = 1447 name: Coraciiformes>,
#   {'betweenness': 0.0040552765544133,
#    'freq': 0.17,
#    'level': 4,
#    'richness': 212}),
#  (<TreeNode type: Order id = 718 name: Magnoliales>,
#   {'betweenness': 0.004054940002975115,
#    'freq': 0.065,
#    'level': 4,
#    'richness': 28}),
#  (<TreeNode type: Order id = 1492 name: Cuculiformes>,
#   {'betweenness': 0.004053257245784188,
#    'freq': 0.2,
#    'level': 4,
#    'richness': 214}),
#  (<TreeNode type: Order id = 7229405 name: Salviniales>,
#   {'betweenness': 0.0034772494593301143,
#    'freq': 0.02,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 1499 name: Agaricales>,
#   {'betweenness': 0.0034772494593301143,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 8}),
#  (<TreeNode type: Order id = 643 name: Isopoda>,
#   {'betweenness': 0.0034772494593301143,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 3}),
#  (<TreeNode type: Order id = 1057 name: Pezizales>,
#   {'betweenness': 0.0034772494593301143,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 3}),
#  (<TreeNode type: Order id = 1496 name: Araneae>,
#   {'betweenness': 0.0034772494593301143,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 3}),
#  (<TreeNode type: Order id = 884 name: Rajiformes>,
#   {'betweenness': 0.0034772494593301143,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 7}),
#  (<TreeNode type: Order id = 461 name: Veneroida>,
#   {'betweenness': 0.0034772494593301143,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 588 name: Pleuronectiformes>,
#   {'betweenness': 0.0034767446321728366,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 11}),
#  (<TreeNode type: Order id = 1296 name: Trichiales>,
#   {'betweenness': 0.0034767446321728366,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 24}),
#  (<TreeNode type: Order id = 783 name: Didelphimorphia>,
#   {'betweenness': 0.0034752301507010026,
#    'freq': 0.16,
#    'level': 4,
#    'richness': 100}),
#  (<TreeNode type: Order id = 552 name: Arecales>,
#   {'betweenness': 0.0034752301507010026,
#    'freq': 0.045,
#    'level': 4,
#    'richness': 17}),
#  (<TreeNode type: Order id = 404 name: Piperales>,
#   {'betweenness': 0.002897876158494188,
#    'freq': 0.11,
#    'level': 4,
#    'richness': 64}),
#  (<TreeNode type: Order id = 1144 name: Russulales>,
#   {'betweenness': 0.002897876158494188,
#    'freq': 0.03,
#    'level': 4,
#    'richness': 9}),
#  (<TreeNode type: Order id = 538 name: Clupeiformes>,
#   {'betweenness': 0.002897876158494188,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 14}),
#  (<TreeNode type: Order id = 811 name: Diptera>,
#   {'betweenness': 0.002897876158494188,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 10}),
#  (<TreeNode type: Order id = 1294 name: Physarales>,
#   {'betweenness': 0.002897876158494188,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 7}),
#  (<TreeNode type: Order id = 7191407 name: Falconiformes>,
#   {'betweenness': 0.002896866504179632,
#    'freq': 0.16,
#    'level': 4,
#    'richness': 219}),
#  (<TreeNode type: Order id = 803 name: Soricomorpha>,
#   {'betweenness': 0.002896866504179632,
#    'freq': 0.105,
#    'level': 4,
#    'richness': 89}),
#  (<TreeNode type: Order id = 7191588 name: Podicipediformes>,
#   {'betweenness': 0.002896866504179632,
#    'freq': 0.095,
#    'level': 4,
#    'richness': 61}),
#  (<TreeNode type: Order id = 1443 name: Craciformes>,
#   {'betweenness': 0.002896866504179632,
#    'freq': 0.09,
#    'level': 4,
#    'richness': 171}),
#  (<TreeNode type: Order id = 7219293 name: Zygophyllales>,
#   {'betweenness': 0.002896866504179632,
#    'freq': 0.065,
#    'level': 4,
#    'richness': 20}),
#  (<TreeNode type: Order id = 1171 name: Dioscoreales>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.075,
#    'level': 4,
#    'richness': 29}),
#  (<TreeNode type: Order id = 7229401 name: Schizaeales>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.045,
#    'level': 4,
#    'richness': 9}),
#  (<TreeNode type: Order id = 872 name: Scorpiones>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.03,
#    'level': 4,
#    'richness': 15}),
#  (<TreeNode type: Order id = 973 name: Spirurida>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 400 name: Proteales>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 1228 name: Thysanoptera>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 11}),
#  (<TreeNode type: Order id = 376 name: Marchantiales>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 381 name: Jungermanniales>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 435 name: Opisthorchiida>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 679 name: Calanoida>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 1003 name: Trichoptera>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 1293 name: Liceales>,
#   {'betweenness': 0.002318839409096447,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 7228685 name: Hymenophyllales>,
#   {'betweenness': 0.002318166306220076,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 1295 name: Stemonitales>,
#   {'betweenness': 0.002318166306220076,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 10}),
#  (<TreeNode type: Order id = 1449 name: Trogoniformes>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.11,
#    'level': 4,
#    'richness': 159}),
#  (<TreeNode type: Order id = 785 name: Lagomorpha>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.085,
#    'level': 4,
#    'richness': 35}),
#  (<TreeNode type: Order id = 7222050 name: Vitales>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.07,
#    'level': 4,
#    'richness': 21}),
#  (<TreeNode type: Order id = 798 name: Primates>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.03,
#    'level': 4,
#    'richness': 13}),
#  (<TreeNode type: Order id = 624 name: Geraniales>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.025,
#    'level': 4,
#    'richness': 9}),
#  (<TreeNode type: Order id = 7223737 name: Picramniales>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.02,
#    'level': 4,
#    'richness': 5}),
#  (<TreeNode type: Order id = 1067 name: Mugiliformes>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 11}),
#  (<TreeNode type: Order id = 421 name: Lycopodiales>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 8}),
#  (<TreeNode type: Order id = 834 name: Cycadales>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 3}),
#  (<TreeNode type: Order id = 620 name: Polytrichales>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 7}),
#  (<TreeNode type: Order id = 7223732 name: Icacinales>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 1180 name: Dictyotales>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 1050 name: Teloschistales>,
#   {'betweenness': 0.001739129556822335,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 726 name: Tinamiformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.05,
#    'level': 4,
#    'richness': 71}),
#  (<TreeNode type: Order id = 839 name: Ciconiiformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.05,
#    'level': 4,
#    'richness': 21}),
#  (<TreeNode type: Order id = 537 name: Characiformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.05,
#    'level': 4,
#    'richness': 19}),
#  (<TreeNode type: Order id = 420 name: Selaginellales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.045,
#    'level': 4,
#    'richness': 20}),
#  (<TreeNode type: Order id = 1336 name: Fissidentales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.035,
#    'level': 4,
#    'richness': 19}),
#  (<TreeNode type: Order id = 636 name: Nymphaeales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.025,
#    'level': 4,
#    'richness': 8}),
#  (<TreeNode type: Order id = 735 name: Cingulata>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.025,
#    'level': 4,
#    'richness': 6}),
#  (<TreeNode type: Order id = 954 name: Equisetales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.02,
#    'level': 4,
#    'richness': 6}),
#  (<TreeNode type: Order id = 7226638 name: Aquifoliales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.02,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 889 name: Synbranchiformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 1491 name: Basommatophora>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 628 name: Garryales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.015,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 496 name: Atheriniformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 8}),
#  (<TreeNode type: Order id = 1494 name: Pilosa>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 5}),
#  (<TreeNode type: Order id = 7222036 name: Crossosomatales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 1451 name: Megaloptera>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 3}),
#  (<TreeNode type: Order id = 472 name: Haplotaxida>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 3}),
#  (<TreeNode type: Order id = 7226589 name: Chloranthales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.01,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 1325 name: Naviculales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 10}),
#  (<TreeNode type: Order id = 614 name: Thalassiophysales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 6}),
#  (<TreeNode type: Order id = 1322 name: Bacillariales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 5}),
#  (<TreeNode type: Order id = 957 name: Notothyladales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 4}),
#  (<TreeNode type: Order id = 556 name: Echinosteliales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 3}),
#  (<TreeNode type: Order id = 619 name: Isobryales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 3}),
#  (<TreeNode type: Order id = 1101 name: Fragilariales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 3}),
#  (<TreeNode type: Order id = 1163 name: Gobiesociformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 3}),
#  (<TreeNode type: Order id = 493 name: Stemmiulida>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 773 name: Syngnathiformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 497 name: Aulopiformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 1186 name: Schizomida>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 1290 name: Hypocreales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 1063 name: Boletales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 2}),
#  (<TreeNode type: Order id = 5939628 name: Buxales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 1270 name: Agyriales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 393 name: Ophioglossales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 969 name: Echinostomida>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 7192754 name: Gaviiformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 1106 name: Batrachoidiformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 1271 name: Acarosporales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 1079 name: Phyllodocida>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 1073 name: Neoechinorhynchida>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 1043 name: Verrucariales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 7190133 name: Opisthopora>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 7229402 name: Cyatheales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 7192755 name: Procellariiformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 1300 name: Cantharellales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 530 name: Thelephorales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 7225533 name: Huerteales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 1247 name: Polydesmida>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 951 name: Isoetales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 7190987 name: Phaethontiformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 499 name: Beryciformes>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 1298 name: Xylariales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 541 name: Ricinulei>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 795 name: Perissodactyla>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 1337 name: Grimmiales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 7224020 name: Sabiales>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1}),
#  (<TreeNode type: Order id = 802 name: Sirenia>,
#   {'betweenness': 0.0011597562559864086,
#    'freq': 0.005,
#    'level': 4,
#    'richness': 1})]

# %%
## Let´s extract the frequency values and store it as a dictionary for further use in the g

# %%
extractfreqs = lambda graph : np.array(map(lambda (k,v) : 
                        v['freq'],graph.nodes(data=True)))

# %%
presences_in_list = extractfreqs(soyunagraphica)

# %%
# Out:
# 0.785

# %% [markdown]
# ## Here we will get the richness for all bats

# %%
bats_richness_per_cell = map(lambda tree :tree.to_Animalia.to_Chordata.to_Mammalia.to_Chiroptera.richness,trees )

# %%
bats_richness_per_cell = pd.DataFrame({'bats_rich' : bats_richness_per_cell})

# %%
coords_cells = st.getCentroidsFromListofCells(cells)

# %%
datafull = pd.concat([bats_richness_per_cell,coords_cells,data],axis=1)

# %%
datafull.loc[:10]

# %%
### Let's save it for posterior use
datafull.to_csv('/outputs/bats_richness.csv')

# %%
from sketches.models import Country
from mesh.models import MexMesh

Mexico = Country.objects.filter(name__contains="exico").get()
mexican_cells = MexMesh.objects.filter(cell__intersects=Mexico.geom)

# %% [markdown]
# ## Obtaining the predictors
# In this case we will bring all the variables to start working with everything

# %%
from raster_api.tools import RasterData
from raster_api.models import raster_models_dic as models

# %% [markdown]
# ### Obtaining everything

# %%
datadict = { key : RasterData(models[key],border=Mexico.geom) for key,value in models.iteritems()}

# %%
#from django.db import connections
#connections.close_all()

# %%
## Without resamling (whole data)
pixel_size = 0.25
# %time datacube_field = map(lambda raster : raster.rescale(pixel_size),datadict.itervalues())
datacube = datacube_field

# %%
map(lambda (k,d) : d.display_field(title=k,origin='Lower'),datadict.iteritems())

# %% [markdown]
# ## For the moment we don't want to do temporal analysis so we need to aggregate the array by the mean.
#
# Using the new 'resample' method

# %%
# Take mean of evetything
cubes = map(lambda (k,v): np.mean(v.toNumpyArray(),axis=0), datadict.iteritems())

# %% [markdown]
# The coordinates are the same so, we can extract the them with getCoordinates and then append everything as a flat array

# %%
coords = map(lambda (k,v) : v.getCoordinates(),datadict.iteritems())

# %%
coords = pd.concat(coords,axis=1)

# %%
coords1 = coords[[0,1]]

# %%
## Oke I need a way to extract the dataframe, maybe aggregate it by mean 
dataframe_cube = map(lambda cube: pd.DataFrame(cube.flatten()),cubes)

# %%
datacube = pd.concat(dataframe_cube,axis=1)

# %%
datacube = pd.concat([datacube,coords1],axis=1)

# %%
datacube.columns = datadict.keys() + list(coords1.columns)

# %%
datacube_clean.columns

# %%
datacube.loc[:10]
datacube_clean = datacube.dropna()

# %%
## Convert to geopandas
from external_plugins.spystats.spystats import tools as tl
datacube_clean = tl.toGeoDataFrame(datacube_clean,xcoord_name='Longitude',ycoord_name='Latitude')

# %% [markdown]
# # Bayesian Modelling
#
# The Model is an inhomogeneous Poisson process.
#
# $y(x) \sim Poisson(\lambda(x)) $
#
# $$ \lambda(x) = exp\{\alpha + S(x)\}$$
#
# Where $S(x)$ is a Gaussian Process such that:
# $$S(x) \sim MVN(0,\sigma^2 \rho(||x - x'||) $$
#
# For this particular case:
# $$\rho = Matern(\phi,\kappa = \frac{3}{4}) + \tau^2$$
#
# I'm using a Bayesian approach with parameters $\phi$ and $\tau$ as random variables with it's corresponding priors.

# %%
datafull.columns

# %%
import pymc3 as pm
#datafull.columns = [u'n_Family', u'Longitude', u'Latitude', u'Elevation_mean',
#       u'MaxTemperature_mean', u'MeanTemperature_mean', u'MinTemperature_mean',
#       u'Precipitation_mean', u'SolarRadiation_mean', u'Vapor_mean',
#       u'WindSpeed_mean', u'geometry']

# %%
datafull[:10]

# %%
ndatafull = datafull.replace('N.A.',np.nan)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import OLS
from statsmodels.genmod.generalized_linear_model import GLM
glmodel = GLM.from_formula('bats_rich ~ Elevation_mean + MeanTemperature_mean',data=ndatafull,family=sm.families.Poisson(sm.families.links.log))
#glmodel = OLS.from_formula('bats_rich ~ WindSpeed_mean',data=datafull)
#glmodel = OLS(ndatafull.bats_rich.values,ndatafull.WindSpeed_mean.values)
res = glmodel.fit()
print(res.summary())


z = np.array([0.0,0.0])
coefs = np.append(z,res.params.values[1:])

# %%
z = np.array([0.0,0.0])
coefs = np.append(z,res.params.values[1:])
print(coefs)

# %%
## Analysis, GP only one parameter to fit
# The variational method is much beter.
from pymc3.variational.callbacks import CheckParametersConvergence

with pm.Model() as model:
    sigma = 1.0
    #range_a=10.13
    
    
    tau = pm.Uniform('tau',0,5.0)
    #sigma = pm.Flat('sigma')
    #phi = pm.HalfNormal('phi',mu=8,sd=3)
    #phi = pm.Uniform('phi',6,12)
    phi = pm.Uniform('phi',0,15)
    
    Tau = pm.gp.cov.Constant(tau)
    
    cov = sigma * pm.gp.cov.Matern32(2,phi,active_dims=[0,1]) + Tau
    #K = cov(grid[['Lon','Lat']].values)
    #phiprint = tt.printing.Print('phi')(phi)
    
    
    mf = pm.gp.mean.Linear(coeffs=coefs,intercept=res.params.values[0])

    
    
    
    
    ## The latent function
    gp = pm.gp.Latent(cov_func=cov)
    
    
    
    
    
    ## I don't know why this
    #f = gp.prior("latent_field", X=data[['Longitude','Latitude']].values,reparameterize=False)
    
    f = gp.prior("latent_field", X=ndatafull[['Longitude','Latitude','Elevation_mean','MaxTemperature_mean']].values,reparameterize=False)
    
    
    
    
    
    
    
    #f_print = tt.printing.Print('latent_field')(f)
    
    y_obs = pm.Poisson('y_obs',mu=np.exp(f),observed=datafull[['bats_rich']].values)
    
    #y_obs = pm.MvNormal('y_obs',mu=np.zeros(n*n),cov=K,observed=grid.Z)

    #gp = pm.gp.Latent(cov_func=cov,observed=sample)
    # Use elliptical slice sampling
    #ess_step = pm.EllipticalSlice(vars=[f_sample], prior_cov=K)
    #step = pm.HamiltonianMC()
    #step = pm.Metropolis()
    #%time trace = pm.sample(5000,step)#,tune=0,chains=1)
    ## Variational
    
    # %time mean_field = pm.fit(method='advi', callbacks=[CheckParametersConvergence()],n=15000)    
    # %time trace = mean_field.sample(draws=5000)

#with model:    
    
    ## For predicting
    #%time f_star = gp.conditional("f_star", data_star.iloc[:,1:3].values)
    #%time f_star = gp.conditional("f_star", small_sample.iloc[:,1:3].values)
    # %time f_star = gp.conditional("f_star", datacube_clean[['Longitude','Latitude','Elevation','MeanTemperature']].values)

    ## Full data
    ##%time f_star = gp.conditional("f_star",elev_data.iloc[:,1:3].values)


    
#with model:
    ## sampling predictions posterior predictive checks
    pred_samples = pm.sample_ppc(trace, vars=[f_star], samples=10)

# %%
preds = pd.DataFrame(pred_samples['f_star']).transpose()

# %%
preds['mean_sample'] = preds.mean(axis=1)

# %%
#preds['idx'] = data_star.index.values
preds['idx'] = datacube_clean.index.values

# %%
#test1 = data_s.merge(preds,how='left',left_index=True,right_on='idx',suffixes=('_obs','_pred'))
test1 = datacube.merge(preds,how='left',left_index=True,right_on='idx',suffixes=('_obs','_pred'))
## Only the values of small_sample
#test2 = elev_data.merge(preds,how='inner',left_index=True,right_on='idx',suffixes=('_obs','_pred'))

# %%
fig, ax = plt.subplots(figsize=(10, 9));
plt.scatter(test1.Longitude,test1.Latitude,c=test1.mean_sample)
plt.scatter(datafull.Longitude,datafull.Latitude,c=datafull.bats_rich,cmap=plt.cm.Greys,s=90)
plt.colorbar()

# %% [markdown]
# # Convert to a raster format.
#  ## Motivation
#  It's important for visualization and compatibility with GIS software to generate the results in a standard raster format.
# *Biospytial* Has incorporated tools for reading and converting to the standard raster formats. In this case Geotif.

# %%
## Import raster container
from raster_api.tools import RasterContainer

# %% [markdown]
# ### The easiest way is to take the metadata (geospatial parameters) from one of the RasterData we used as covariates

# %%
elv_rast = datadict['Elevation'].rasterdata

# %%
predicted_data = test1.mean_sample.values

# %%
ncounts_families = RasterContainer(predicted_data,use_metadata_from=elv_rast)

# %%
ncounts_families.display_field(band=1,origin='Lower',title='log(family richness)')

# %%
np.log(2)

# %%
fig, ax = plt.subplots(figsize=(10, 9));

#ncounts_families.display_field(band=2,origin='Lower',title='family richness')
plt.imshow(ncounts_families.rasterdata.bands[1].data(),origin='Lower')
plt.colorbar(orientation='horizontal')

# %% [markdown]
# ### Export to Geotif

# %%
ncounts_families.exportToGeoTiff('bats_richness_fromsample')

# %% [markdown]
# There are several parameters hidden here:
#     1. The size of the predictors grid
#     2. The sample size of the training data
#     3. The bayesian hyperparameters

# %% [markdown]
# ## For implementing today
# * The modeller function (structure):
#
#    * Inputs:
#
#     ** Dataframe for training data
#
#     ** numpy n-array or dataframe for predictors
#
#     ** Model (specified as Pymc3 model)
#
#     * Outputs:
#
#         *** The new RasterContainer with rthe bands as: log, exp and expit (in case binomial)
#
# * Seems like needs to be a premodelr to select the cells, the geometry, etc.

# %%
ncounts_families.rasterdata.bands[0].data().shape

# %% [markdown]
# ## stages
# 1. Build a function for extracting the predictors given a scale parameter
# 2. Build a function for the "premodeling"
# 3. Build a function for bundling everything and return the prediction (needs to accept a model)
#
# > Models to run
# Show two maps of taxa. e.g. Agave and Bats for instance
#
# Then also show the matrix distance for trees
